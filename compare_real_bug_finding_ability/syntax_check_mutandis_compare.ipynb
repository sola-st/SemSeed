# %% [markdown]
# # Find bug seeding patterns
# ---
# We want to find seeding patterns that may be used by SemSeed. This is supposed
# to create a table comparing *Mutandis*.

# %%
import pandas as pd
import json
import os
from pathlib import Path
import codecs
import json
from typing import List, Dict, Any
import pandas as pd
from multiprocessing import Pool, cpu_count
from tqdm.notebook import trange, tqdm
benchmarks_dir = '../benchmarks'

# SemSeed
seeded_bugs_file_path  = os.path.join(benchmarks_dir, 'js_benchmark_seeded_bugs_efficiency_test.pkl')
seeded_bugs_files_dir  = os.path.join(benchmarks_dir, 'js_benchmark_seeded_bugs_efficiency_test')

# %%
def read_json_file(json_file_path)->Dict:
    try:
        obj_text = codecs.open(json_file_path, 'r', encoding='utf-8').read()
        r = json.loads(obj_text)
        return r
    except FileNotFoundError:
        print(
            "Please provide a correct file p. Eg. ./results/validated-conflicts.json")
        return {}
    except Exception as e:
        # Empty JSON file most likely due to abrupt killing of the process while writing
        # print (e)
        return {}

def read_dataset_given_files(extracted_data_files: List) -> pd.DataFrame:
    d = []
    with Pool(cpu_count()) as p:
        with tqdm(total=len(extracted_data_files)) as pbar:
            pbar.set_description_str(
                desc="Reading dataset from files", refresh=False)
            for i, each_vars in enumerate(
                    p.imap_unordered(read_json_file, extracted_data_files, 20)):
                pbar.update()
                d.append(each_vars)
            p.close()
            p.join()
    # print(d)
    extracted_dataset = pd.DataFrame(d)
    return extracted_dataset

def file_path_to_dataset(dataset_file_path, dir_path):
    if not Path(dataset_file_path).is_file():
        file_paths = list(Path(dir_path).rglob('*.json'))
        print(f"Number of files={len(file_paths)}")
        dataset = read_dataset_given_files(extracted_data_files=file_paths)
        print(f"Saving {dataset_file_path}")
        dataset.to_pickle(dataset_file_path,'gzip')
    else:
        print(f'Reading from {dataset_file_path}')
        dataset = pd.read_pickle(dataset_file_path,'gzip')
    print(f"Dataset contains {len(dataset)} examples")
    return dataset

# %%
seeded_bugs = file_path_to_dataset(dataset_file_path=seeded_bugs_file_path, dir_path=seeded_bugs_files_dir)
# Out:
# Reading from ../../../benchmarks/js_benchmark_seeded_bugs_efficiency_test.pkl
# Dataset contains 677217 examples

# %% [markdown]
# ### Syntax errors in seeded bugs
# The above bugs have been seeded on a random sample of 1000 files.

# %%
print(f'Seeded {len(seeded_bugs)} bugs on random sample of 1000 files')
# Out:
# Seeded 677217 bugs on random sample of 1000 files

# %%
syntax_check = read_json_file(os.path.join(benchmarks_dir,'file_and_syntax_correct.json'))
inc = 0
for f,v in syntax_check.items():
    if not v:
        inc+=1
print(f'{inc} or {inc/len(seeded_bugs)*100}% Syntactically incorrect')
# Out:
# 20320 or 3.0005153444169297% Syntactically incorrect

# %%
def get_only_idf_lit_containing_patterns(all_changes):
    """
    It is possible that every bug-fix pattern can not be used to seed bugs.
    We filter some of them here. For example:
        * we may filter very long change patterns (although we do it once while aggregating data from MongoDB)
        * we may select only those chage patterns that has atleast 'N' frequency
    """
    filtered_change_patterns = []

    # # ----------------------- Filtering number of tokens -------------------------
    # max_number_of_tokens = 10
    # for change_pattern in self.all_training_change_patterns:
    #     print('\n\n \t *** ***  Selecting only change patterns having total {} tokens *** ***'.format(max_number_of_tokens*2))
    #     if len(change_pattern['fix']) <= max_number_of_tokens and len(change_pattern['buggy']) <= max_number_of_tokens:
    #         filtered_change_patterns.append(change_pattern)

    # ----------------------- Filtering based on the frequency of the change patterns -----------------
    # min_frequency = 4
    # print('\n \t *** ***  Filtering only change patterns having minimum frequency  {} *** ***\n'.format(min_frequency))
    # mapping_of_change_patterns = SeedBugs._str_mapping_change_pattern_to_change(
    #     all_changes)

    # for mapped_seq in mapping_of_change_patterns:
    #     if len(mapping_of_change_patterns[mapped_seq]) >= min_frequency:
    #         filtered_change_patterns.extend(
    #             mapping_of_change_patterns[mapped_seq])

    # print("\tTotal {} change patterns and {} filtered change patterns ".format(
    #     len(mapping_of_change_patterns), len(filtered_change_patterns)))

    # ------------------- Remove those change patterns that does not contain any Identifiers/Literals ------------
    for t in all_changes:
        # If the change pattern contains at-least one Identifier/Literal, we use that.
        # Else the change pattern is discarded
        if 'Idf_' in ' '.join(t['fix']) or 'Idf_' in ' '.join(t['buggy']) or 'Lit_' in ' '.join(
                t['fix']) or 'Lit_' in ' '.join(t['buggy']):
            filtered_change_patterns.append(t)

    return filtered_change_patterns

# %%
with open(os.path.join(benchmarks_dir, 'training_changes.json'),'r') as f:
    patterns = json.load(f)
patterns = get_only_idf_lit_containing_patterns(patterns)
patterns  = pd.DataFrame(patterns)
print(f'Found {len(patterns)} patterns')
# Out:
# Found 2880 patterns

# %%
def select_only_single_token_changes(all_change_patterns):
    only_single_operator_change = []
    only_single_idf_change = []
    only_single_lit_change = []

    for _,r in patterns.iterrows():
        pattern = r.to_dict()
        # Operator ------------------
        f = []
        b = []
        for t in pattern['fix']:
            if 'Lit_' not in t and 'Idf_' not in t:
                f.append(t)
        for t in pattern['buggy']:
            if 'Lit_' not in t and 'Idf_' not in t:
                b.append(t)
        
        di_f_b_op = len(set(f)-set(b)) == 1
        di_b_f_op = len(set(b)-set(f)) == 1
        

        # Identifier and Literal ------------
        f_idf = []
        b_idf = []
        for t in pattern['fix']:
            if 'Idf_' in t:
                f_idf.append(t)
        for t in pattern['buggy']:
            if 'Idf_' in t:
                b_idf.append(t)
        
        di_f_b_idf = len(set(f_idf)-set(b_idf)) == 1
        di_b_f_idf = len(set(b_idf)-set(f_idf)) == 1
        
        
        
        f_lit = []
        b_lit = []
        for t in pattern['fix']:
            if 'Lit_' in t:
                f_lit.append(t)
        for t in pattern['buggy']:
            if 'Lit_' in t:
                b_lit.append(t)
        
        di_f_b_lit = len(set(f_lit)-set(b_lit)) == 1
        di_b_f_lit = len(set(b_lit)-set(f_lit)) == 1
        
        if di_f_b_op and di_b_f_op and di_f_b_idf==0==di_b_f_idf and di_f_b_lit==0== di_b_f_lit:
            only_single_operator_change.append(pattern)

        if di_f_b_idf and di_b_f_idf and di_f_b_op == 0 == di_b_f_op and di_f_b_lit==0== di_b_f_lit:
            only_single_idf_change.append(pattern)

        if di_f_b_lit and di_b_f_lit and di_f_b_op == 0 == di_b_f_op and di_f_b_idf==0==di_b_f_idf:
            only_single_lit_change.append(pattern)
    return pd.DataFrame(only_single_operator_change), pd.DataFrame(only_single_idf_change), pd.DataFrame(only_single_lit_change)

single_operator_patterns, single_idf_patterns, single_lit_patterns = select_only_single_token_changes(patterns)

# %%
single_operator_patterns
# Out:
#                                                   _id  \
# 0   mozilla/pdf.js_406c2b2f2b5dfeda4c5ab1132965e9a...
# 1   mozilla/pdf.js_2ad3a8bd1c3e237a310239de168709d...
# 2   sequelize/sequelize_1b593a74942ce2295a2a767823...
# 3   mozilla/pdf.js_499a9b0146bf2b0dbf06963e16a970c...
# 4   adobe/brackets_af1eba2ea6344298763e77b725e54a2...
# ..                                                ...
# 69  serverless/serverless_178fab9473a4704ee1640138...
# 70  nodejs/node_fc6f487f2e2eaa54e2de38b1cf9529dec5...
# 71  RocketChat/Rocket.Chat_69b78031e98827de07929d1...
# 72  expressjs/express_daf66beda49ebac6086b81dd1896...
# 73  nodejs/node_4f1eddf84e963f9c19e26259db7cf65cf2...
#
#                                  commit_hash           commit_time  \
# 0   406c2b2f2b5dfeda4c5ab1132965e9ad7844e05c  23/08/2011, 16:49:25
# 1   2ad3a8bd1c3e237a310239de168709d8143d5d9c  24/09/2011, 04:29:01
# 2   1b593a74942ce2295a2a767823dbea22d5efc30b  11/12/2011, 12:07:13
# 3   499a9b0146bf2b0dbf06963e16a970c4fa8f1586  12/01/2012, 16:15:45
# 4   af1eba2ea6344298763e77b725e54a2eb545d3fd  07/04/2012, 02:29:25
# ..                                       ...                   ...
# 69  178fab9473a4704ee16401381ad58f097806a72a  01/06/2017, 08:35:37
# 70  fc6f487f2e2eaa54e2de38b1cf9529dec5f8fcd5  05/06/2017, 22:44:12
# 71  69b78031e98827de07929d1b33d4bc2c83362e2a  24/06/2017, 13:04:54
# 72  daf66beda49ebac6086b81dd1896a34395306a71  04/08/2017, 03:20:55
# 73  4f1eddf84e963f9c19e26259db7cf65cf287d45e  16/08/2017, 11:31:21
#
#                         local_repo_path  \
# 0        ../results/top_JS_repos/pdf.js
# 1        ../results/top_JS_repos/pdf.js
# 2     ../results/top_JS_repos/sequelize
# 3        ../results/top_JS_repos/pdf.js
# 4      ../results/top_JS_repos/brackets
# ..                                  ...
# 69   ../results/top_JS_repos/serverless
# 70         ../results/top_JS_repos/node
# 71  ../results/top_JS_repos/Rocket.Chat
# 72      ../results/top_JS_repos/express
# 73         ../results/top_JS_repos/node
#
#                                                   url  \
# 0   https://github.com/mozilla/pdf.js/commit/406c2...
# 1   https://github.com/mozilla/pdf.js/commit/2ad3a...
# 2   https://github.com/sequelize/sequelize/commit/...
# 3   https://github.com/mozilla/pdf.js/commit/499a9...
# 4   https://github.com/adobe/brackets/commit/af1eb...
# ..                                                ...
# 69  https://github.com/serverless/serverless/commi...
# 70  https://github.com/nodejs/node/commit/fc6f487f...
# 71  https://github.com/RocketChat/Rocket.Chat/comm...
# 72  https://github.com/expressjs/express/commit/da...
# 73  https://github.com/nodejs/node/commit/4f1eddf8...
#
#                                                   fix        fix_tokenType  \
# 0               [this, ., Idf_1, ., Idf_2, <=, Idf_3]     BinaryExpression
# 1   [!, Idf_1, (, Idf_2, ), ||, Idf_2, ., Idf_3, !...    LogicalExpression
# 2                          [typeof, Idf_1, !=, Lit_1]     BinaryExpression
# 3               [Idf_1, ., Idf_2, ., Idf_3, >, Lit_1]     BinaryExpression
# 4              [Idf_1, ., Idf_2, >=, Idf_3, ., Idf_4]     BinaryExpression
# ..                                                ...                  ...
# 69  [`Missing "handler" property in function "${, ...      TemplateLiteral
# 70                 [var, Idf_1, =, `${, Idf_2, }`, ;]  VariableDeclaration
# 71                         [const, Idf_1, =, [, ], ;]  VariableDeclaration
# 72  [Idf_1, ., Idf_2, (, Idf_3, ., Idf_4, (, Idf_5...  ExpressionStatement
# 73  [const, Idf_1, =, `"${, Idf_2, ., Idf_3, }" -e...  VariableDeclaration
#
#                                         fix_file_path  \
# 0                                              pdf.js
# 1                                              pdf.js
# 2             lib/connectors/mysql/query-generator.js
# 3                                       web/viewer.js
# 4                       src/editor/CSSInlineEditor.js
# ..                                                ...
# 69  lib/plugins/aws/package/compile/functions/inde...
# 70                    lib/internal/process/warning.js
# 71  packages/rocketchat-analytics/client/loadScrip...
# 72                              examples/ejs/index.js
# 73  test/parallel/test-child-process-exec-maxBuffe...
#
#                                            fix_actual         fix_range  \
# 0   [this, ., current, ., fontSize, <=, kRasterize...  [152702, 152741]
# 1   [!, IsArray, (, obj, ), ||, obj, ., length, !=...  [104589, 104622]
# 2                   [typeof, indexName, !=, 'string']      [7877, 7905]
# 3          [textDiv, ., dataset, ., textLength, >, 1]    [30845, 30875]
# 4   [cursorCoords, ., x, >=, ruleListOffset, ., left]    [15860, 15897]
# ..                                                ...               ...
# 69  [`Missing "handler" property in function "${, ...      [3743, 3802]
# 70                  [var, msg, =, `${, prefix, }`, ;]      [2158, 2180]
# 71                       [const, domains, =, [, ], ;]      [1364, 1383]
# 72  [app, ., use, (, express, ., static, (, path, ...        [671, 727]
# 73  [const, cmd, =, `"${, process, ., execPath, }"...        [913, 983]
#
#      fix_line                                              buggy  \
# 0   4730-4730               [this, ., Idf_1, ., Idf_2, <, Idf_3]
# 1   3325-3325  [!, Idf_1, (, Idf_2, ), ||, Idf_2, ., Idf_3, =...
# 2     213-213                         [typeof, Idf_1, ==, Lit_1]
# 3     976-976             [Idf_1, ., Idf_2, ., Idf_3, >=, Lit_1]
# 4     353-353              [Idf_1, ., Idf_2, >, Idf_3, ., Idf_4]
# ..        ...                                                ...
# 69    101-101  [`Missing "handler" property in function ""${,...
# 70      93-93                 [let, Idf_1, =, `${, Idf_2, }`, ;]
# 71      30-30                           [let, Idf_1, =, [, ], ;]
# 72      29-29  [Idf_1, ., Idf_2, (, Idf_3, ., Idf_4, (, Idf_5...
# 73      39-39  [const, Idf_1, =, `"${, Idf_2, ., Idf_3, }" -e...
#
#         buggy_tokenType                                    buggy_file_path  \
# 0      BinaryExpression                                             pdf.js
# 1     LogicalExpression                                             pdf.js
# 2      BinaryExpression            lib/connectors/mysql/query-generator.js
# 3      BinaryExpression                                      web/viewer.js
# 4      BinaryExpression                      src/editor/CSSInlineEditor.js
# ..                  ...                                                ...
# 69      TemplateLiteral  lib/plugins/aws/package/compile/functions/inde...
# 70  VariableDeclaration                    lib/internal/process/warning.js
# 71  VariableDeclaration  packages/rocketchat-analytics/client/loadScrip...
# 72  ExpressionStatement                              examples/ejs/index.js
# 73  VariableDeclaration  test/parallel/test-child-process-exec-maxBuffe...
#
#                                          buggy_actual       buggy_range  \
# 0   [this, ., current, ., fontSize, <, kRasterizer...  [152702, 152740]
# 1   [!, IsArray, (, obj, ), ||, obj, ., length, ==...  [104589, 104622]
# 2                   [typeof, indexName, ==, 'string']      [7877, 7905]
# 3         [textDiv, ., dataset, ., textLength, >=, 1]    [30845, 30876]
# 4    [cursorCoords, ., x, >, ruleListOffset, ., left]    [15860, 15896]
# ..                                                ...               ...
# 69  [`Missing "handler" property in function ""${,...      [3743, 3803]
# 70                  [let, msg, =, `${, prefix, }`, ;]      [2158, 2180]
# 71                         [let, domains, =, [, ], ;]      [1364, 1381]
# 72  [app, ., use, (, express, ., static, (, path, ...        [671, 728]
# 73  [const, cmd, =, `"${, process, ., execPath, }"...        [913, 978]
#
#    buggy_line
# 0   4730-4730
# 1   3325-3325
# 2     213-213
# 3     976-976
# 4     353-353
# ..        ...
# 69    101-101
# 70      93-93
# 71      30-30
# 72      29-29
# 73      39-39
#
# [74 rows x 17 columns]

# %%
single_idf_patterns
# Out:
#                                                    _id  \
# 0    jquery/jquery_065cd7ecf62c7b2ad5b58d447aca7a9c...
# 1    jquery/jquery_ea53a61a38ecdddaea6f344fcaf74bfe...
# 2    jquery/jquery_cafd40805a20d02fe1a904a4c0a0cc6f...
# 3    jquery/jquery_f38251b2ce84a0ab6302475786c3e721...
# 4    jquery/jquery_5736e8d90d5c7961e19cb707301d9f58...
# ..                                                 ...
# 391  transloadit/uppy_198cdee73369aa585b4c021e56639...
# 392  transloadit/uppy_336e7d1663e244831df2bedddc8a9...
# 393  transloadit/uppy_ae530aed6a257ff091b38546d9eb0...
# 394  RocketChat/Rocket.Chat_94699eefc29743da8ab0f03...
# 395  RocketChat/Rocket.Chat_6016e05cf7ac5f2da8a5b61...
#
#                                   commit_hash           commit_time  \
# 0    065cd7ecf62c7b2ad5b58d447aca7a9cdb6f7bcb  18/08/2006, 06:13:13
# 1    ea53a61a38ecdddaea6f344fcaf74bfe1d37397c  15/09/2006, 00:28:25
# 2    cafd40805a20d02fe1a904a4c0a0cc6f0c525f80  10/10/2006, 17:00:54
# 3    f38251b2ce84a0ab6302475786c3e721dba2177c  10/09/2007, 01:17:30
# 4    5736e8d90d5c7961e19cb707301d9f58daa0aa3b  18/10/2007, 19:25:08
# ..                                        ...                   ...
# 391  198cdee73369aa585b4c021e56639062020309e6  06/08/2017, 09:59:35
# 392  336e7d1663e244831df2bedddc8a9f2cb983053d  09/08/2017, 18:19:23
# 393  ae530aed6a257ff091b38546d9eb00dbbba3dc39  30/08/2017, 14:21:51
# 394  94699eefc29743da8ab0f03c6937cde35f359a21  31/08/2017, 16:32:14
# 395  6016e05cf7ac5f2da8a5b61b3ada31f34a5b9e4e  06/09/2017, 00:56:46
#
#                          local_repo_path  \
# 0         ../results/top_JS_repos/jquery
# 1         ../results/top_JS_repos/jquery
# 2         ../results/top_JS_repos/jquery
# 3         ../results/top_JS_repos/jquery
# 4         ../results/top_JS_repos/jquery
# ..                                   ...
# 391         ../results/top_JS_repos/uppy
# 392         ../results/top_JS_repos/uppy
# 393         ../results/top_JS_repos/uppy
# 394  ../results/top_JS_repos/Rocket.Chat
# 395  ../results/top_JS_repos/Rocket.Chat
#
#                                                    url  \
# 0    https://github.com/jquery/jquery/commit/065cd7...
# 1    https://github.com/jquery/jquery/commit/ea53a6...
# 2    https://github.com/jquery/jquery/commit/cafd40...
# 3    https://github.com/jquery/jquery/commit/f38251...
# 4    https://github.com/jquery/jquery/commit/5736e8...
# ..                                                 ...
# 391  https://github.com/transloadit/uppy/commit/198...
# 392  https://github.com/transloadit/uppy/commit/336...
# 393  https://github.com/transloadit/uppy/commit/ae5...
# 394  https://github.com/RocketChat/Rocket.Chat/comm...
# 395  https://github.com/RocketChat/Rocket.Chat/comm...
#
#                                                    fix        fix_tokenType  \
# 0                       [Idf_1, ., Idf_2, [, Idf_3, ]]     MemberExpression
# 1                    [Idf_1, ., Idf_2, (, Idf_3, ), ;]  ExpressionStatement
# 2                       [!, Idf_1, ., Idf_2, ., Idf_3]      UnaryExpression
# 3                                    [Idf_1, :, Lit_1]             Property
# 4    [Idf_1, ., Idf_2, ., Idf_3, &&, Idf_4, [, Lit_...    LogicalExpression
# ..                                                 ...                  ...
# 391  [return, `${, this, ., Idf_1, ., Idf_2, }/${, ...      ReturnStatement
# 392                   [this, ., Idf_1, ., Idf_2, (, )]       CallExpression
# 393            [this, ., Idf_1, ., Idf_2, (, Idf_3, )]  ExpressionStatement
# 394  [Idf_1, =, Idf_2, ., Idf_3, ., Idf_4, (, Idf_1...  ExpressionStatement
# 395  [Idf_1, =, Idf_2, ., Idf_3, ., Idf_4, (, Idf_1...  ExpressionStatement
#
#                                          fix_file_path  \
# 0                                 src/jquery/jquery.js
# 1                                 src/jquery/jquery.js
# 2                                         src/fx/fx.js
# 3                                          src/core.js
# 4                                          src/core.js
# ..                                                 ...
# 391              src/uppy-base/src/plugins/Provider.js
# 392                src/generic-provider-views/index.js
# 393                        src/plugins/Webcam/index.js
# 394  packages/rocketchat-autotranslate/server/autot...
# 395  packages/rocketchat-autotranslate/server/autot...
#
#                                             fix_actual       fix_range  \
# 0                             [jQuery, ., fn, [, n, ]]  [24094, 24108]
# 1                   [args, ., unshift, (, event, ), ;]  [68660, 68682]
# 2                        [!, z, ., el, ., oldOverflow]  [16240, 16257]
# 3      [prevAll, :, "jQuery.dir(a,'previousSibling')"]  [26728, 26770]
# 4    [jQuery, ., browser, ., safari, &&, window, [,...  [36258, 36307]
# ..                                                 ...             ...
# 391  [return, `${, this, ., opts, ., host, }/${, th...      [795, 840]
# 392            [this, ., Provider, ., checkAuth, (, )]    [3083, 3108]
# 393            [this, ., core, ., addFile, (, file, )]    [5359, 5382]
# 394  [message, =, RocketChat, ., Markdown, ., parse...    [2661, 2716]
# 395  [message, =, RocketChat, ., Markdown, ., parse...    [2661, 2716]
#
#       fix_line                                              buggy  \
# 0      856-856                     [Idf_1, ., Idf_2, [, Idf_4, ]]
# 1    2135-2135                  [Idf_1, ., Idf_4, (, Idf_3, ), ;]
# 2      512-512                     [!, Idf_1, ., Idf_2, ., Idf_4]
# 3    1023-1023                                  [Idf_2, :, Lit_1]
# 4    1299-1299  [Idf_1, ., Idf_2, ., Idf_3, &&, Idf_6, [, Lit_...
# ..         ...                                                ...
# 391      36-36  [return, `${, this, ., Idf_1, ., Idf_2, }/${, ...
# 392      99-99                   [this, ., Idf_1, ., Idf_3, (, )]
# 393    171-171            [this, ., Idf_1, ., Idf_4, (, Idf_3, )]
# 394      94-94  [Idf_1, =, Idf_2, ., Idf_3, ., Idf_5, (, Idf_1...
# 395      94-94  [Idf_1, =, Idf_2, ., Idf_3, ., Idf_5, (, Idf_1...
#
#          buggy_tokenType                                    buggy_file_path  \
# 0       MemberExpression                               src/jquery/jquery.js
# 1    ExpressionStatement                               src/jquery/jquery.js
# 2        UnaryExpression                                       src/fx/fx.js
# 3               Property                                        src/core.js
# 4      LogicalExpression                                        src/core.js
# ..                   ...                                                ...
# 391      ReturnStatement              src/uppy-base/src/plugins/Provider.js
# 392       CallExpression                src/generic-provider-views/index.js
# 393  ExpressionStatement                        src/plugins/Webcam/index.js
# 394  ExpressionStatement  packages/rocketchat-autotranslate/server/autot...
# 395  ExpressionStatement  packages/rocketchat-autotranslate/server/autot...
#
#                                           buggy_actual     buggy_range  \
# 0                             [jQuery, ., fn, [, i, ]]  [24094, 24108]
# 1                  [args, ., unshiftT, (, event, ), ;]  [68660, 68683]
# 2                         [!, z, ., el, ., oldOverlay]  [16240, 16256]
# 3     [prevtAll, :, "jQuery.dir(a,'previousSibling')"]  [26728, 26771]
# 4    [jQuery, ., browser, ., safari, &&, self, [, "...  [36258, 36305]
# ..                                                 ...             ...
# 391  [return, `${, this, ., opts, ., host, }/${, th...      [795, 850]
# 392                 [this, ., Provider, ., auth, (, )]    [3083, 3103]
# 393            [this, ., core, ., addfile, (, file, )]    [5359, 5382]
# 394  [message, =, RocketChat, ., Markdown, ., parse...    [2661, 2706]
# 395  [message, =, RocketChat, ., Markdown, ., parse...    [2661, 2706]
#
#     buggy_line
# 0      856-856
# 1    2135-2135
# 2      512-512
# 3    1023-1023
# 4    1299-1299
# ..         ...
# 391      36-36
# 392      99-99
# 393    171-171
# 394      94-94
# 395      94-94
#
# [396 rows x 17 columns]

# %%
single_lit_patterns
# Out:
#                                                    _id  \
# 0    jquery/jquery_69ae9aeab0bae23f0fb6673d5ad58ffc...
# 1    jquery/jquery_32548da2476603b40df3a15afb536b27...
# 2    jquery/jquery_f7efcc858dec55fa3b9babb94ebc73b0...
# 3    jquery/jquery_18e563abe53d7a7fb4169c869f01812c...
# 4    jquery/jquery_c136717119ec986be67848ec45b56e23...
# ..                                                 ...
# 801  adobe/brackets_fa18156fccd896a64aa107594228073...
# 802  serverless/serverless_490f517d1219c58f12438884...
# 803  mrdoob/three.js_45c15c792f448502d1da1eabb73c21...
# 804  RocketChat/Rocket.Chat_47cf56f20a6e7aabecc540e...
# 805  select2/select2_5f7feeb8016035730bf24c56a6127a...
#
#                                   commit_hash           commit_time  \
# 0    69ae9aeab0bae23f0fb6673d5ad58ffce44c7841  06/06/2006, 14:51:44
# 1    32548da2476603b40df3a15afb536b2750321aec  05/07/2006, 04:03:38
# 2    f7efcc858dec55fa3b9babb94ebc73b0888e6d51  31/08/2006, 05:59:51
# 3    18e563abe53d7a7fb4169c869f01812c119ae191  01/09/2006, 01:30:29
# 4    c136717119ec986be67848ec45b56e23d77d51fd  30/11/2006, 00:25:33
# ..                                        ...                   ...
# 801  fa18156fccd896a64aa107594228073f42addad4  22/08/2017, 21:10:19
# 802  490f517d1219c58f12438884409e11f6613e6a2e  26/08/2017, 12:41:25
# 803  45c15c792f448502d1da1eabb73c217df4275c3c  06/09/2017, 03:23:41
# 804  47cf56f20a6e7aabecc540e47df583464fc511c4  06/09/2017, 15:40:43
# 805  5f7feeb8016035730bf24c56a6127a66aad5ffee  06/09/2017, 19:41:31
#
#                          local_repo_path  \
# 0         ../results/top_JS_repos/jquery
# 1         ../results/top_JS_repos/jquery
# 2         ../results/top_JS_repos/jquery
# 3         ../results/top_JS_repos/jquery
# 4         ../results/top_JS_repos/jquery
# ..                                   ...
# 801     ../results/top_JS_repos/brackets
# 802   ../results/top_JS_repos/serverless
# 803     ../results/top_JS_repos/three.js
# 804  ../results/top_JS_repos/Rocket.Chat
# 805      ../results/top_JS_repos/select2
#
#                                                    url  \
# 0    https://github.com/jquery/jquery/commit/69ae9a...
# 1    https://github.com/jquery/jquery/commit/32548d...
# 2    https://github.com/jquery/jquery/commit/f7efcc...
# 3    https://github.com/jquery/jquery/commit/18e563...
# 4    https://github.com/jquery/jquery/commit/c13671...
# ..                                                 ...
# 801  https://github.com/adobe/brackets/commit/fa181...
# 802  https://github.com/serverless/serverless/commi...
# 803  https://github.com/mrdoob/three.js/commit/45c1...
# 804  https://github.com/RocketChat/Rocket.Chat/comm...
# 805  https://github.com/select2/select2/commit/5f7f...
#
#                                                    fix        fix_tokenType  \
# 0                                    [Lit_1, :, Lit_2]             Property
# 1    [var, Idf_1, =, Idf_2, ., Idf_3, (, this, ., I...  VariableDeclaration
# 2                                    [Idf_1, :, Lit_1]             Property
# 3    [Idf_1, :, Lit_1, ., Idf_2, (, Idf_3, ), &&, !...             Property
# 4                            [var, Idf_1, =, Lit_1, ;]  VariableDeclaration
# ..                                                 ...                  ...
# 801                                  [Lit_1, :, Lit_2]             Property
# 802  [Idf_1, (, Idf_2, ., Idf_3, ), ., Idf_4, ., Id...  ExpressionStatement
# 803                 [(, Idf_1, &, Lit_1, ), <<, Lit_2]     BinaryExpression
# 804                                 [return, Lit_1, ;]      ReturnStatement
# 805                                 [return, Lit_1, ;]      ReturnStatement
#
#                                          fix_file_path  \
# 0                                     jquery/jquery.js
# 1                                     jquery/jquery.js
# 2                                 src/jquery/jquery.js
# 3                                 src/jquery/jquery.js
# 4                                  build/build/lite.js
# ..                                                 ...
# 801                              src/nls/hr/strings.js
# 802       lib/plugins/aws/provider/awsProvider.test.js
# 803                     examples/js/libs/msgpack-js.js
# 804  packages/rocketchat-ui/client/lib/textarea-aut...
# 805                          src/js/select2/i18n/es.js
#
#                                             fix_actual       fix_range  \
# 0     ['#', :, "a.attributes['id'].nodeValue == m[2]"]    [9350, 9393]
# 1    [var, ret, =, jQuery, ., map, (, this, ., cur,...    [6344, 6390]
# 2        [children, :, "jQuery.sibling(a.firstChild)"]  [67382, 67422]
# 3    [mozilla, :, /mozilla/, ., test, (, b, ), &&, ...  [47894, 47954]
# 4    [var, blockMatch, =, /\s*\/\*\*\s*((.|\n|\r\n)...        [32, 90]
# ..                                                 ...             ...
# 801  ["ERROR_PREFS_CORRUPT_TITLE", :, "Greška prili...    [4243, 4322]
# 802  [expect, (, err, ., message, ), ., to, ., cont...    [6782, 6834]
# 803                       [(, byte, &, 0x1f, ), <<, 6]    [2644, 2662]
# 804                                  [return, true, ;]    [2027, 2039]
# 805  [return, 'No se pudieron cargar los resultados...       [83, 129]
#
#       fix_line                                              buggy  \
# 0      401-401                                  [Lit_1, :, Lit_3]
# 1      274-274  [var, Idf_1, =, Idf_2, ., Idf_3, (, this, ., I...
# 2    2386-2386                                  [Idf_1, :, Lit_2]
# 3    1656-1656  [Idf_1, :, Lit_1, ., Idf_2, (, Idf_3, ), &&, !...
# 4          3-3                          [var, Idf_1, =, Lit_2, ;]
# ..         ...                                                ...
# 801      65-65                                  [Lit_1, :, Lit_3]
# 802    241-241  [Idf_1, (, Idf_2, ., Idf_3, ), ., Idf_4, ., Id...
# 803      90-90                 [(, Idf_1, &, Lit_3, ), <<, Lit_2]
# 804      67-67                                 [return, Lit_2, ;]
# 805        5-5                                 [return, Lit_2, ;]
#
#          buggy_tokenType                                    buggy_file_path  \
# 0               Property                                   jquery/jquery.js
# 1    VariableDeclaration                                   jquery/jquery.js
# 2               Property                               src/jquery/jquery.js
# 3               Property                               src/jquery/jquery.js
# 4    VariableDeclaration                                build/build/lite.js
# ..                   ...                                                ...
# 801             Property                              src/nls/hr/strings.js
# 802  ExpressionStatement       lib/plugins/aws/provider/awsProvider.test.js
# 803     BinaryExpression                     examples/js/libs/msgpack-js.js
# 804      ReturnStatement  packages/rocketchat-ui/client/lib/textarea-aut...
# 805      ReturnStatement                          src/js/select2/i18n/es.js
#
#                                           buggy_actual     buggy_range  \
# 0             ['#', :, "a.getAttribute('id') == m[2]"]    [9350, 9385]
# 1    [var, ret, =, jQuery, ., map, (, this, ., cur,...    [6344, 6390]
# 2                        [children, :, "a.childNodes"]  [67382, 67406]
# 3    [mozilla, :, /mozilla/, ., test, (, b, ), &&, ...  [47894, 47945]
# 4    [var, blockMatch, =, /\s*\/\*\*\s*((.|\n)*?)\s...        [32, 85]
# ..                                                 ...             ...
# 801  ["ERROR_PREFS_CORRUPT_TITLE", :, "Greška prili...    [4243, 4320]
# 802  [expect, (, err, ., message, ), ., to, ., cont...    [6782, 6837]
# 803                       [(, byte, &, 0x0f, ), <<, 6]    [2644, 2662]
# 804                                 [return, false, ;]    [2027, 2040]
# 805                      [return, 'La carga falló', ;]       [83, 107]
#
#     buggy_line
# 0      401-401
# 1      274-274
# 2    2386-2386
# 3    1656-1656
# 4          3-3
# ..         ...
# 801      65-65
# 802    241-241
# 803      90-90
# 804      67-67
# 805        5-5
#
# [806 rows x 17 columns]

# %%
patterns
# Out:
#                                                     _id  \
# 0     jquery/jquery_c75701a0152a589c21c4862c33b69190...
# 1     jquery/jquery_65b1081e9e9f9b8c4a0f1621c98e823e...
# 2     jquery/jquery_69ae9aeab0bae23f0fb6673d5ad58ffc...
# 3     jquery/jquery_a457262ef5bcb163417a1f6db0b770f1...
# 4     jquery/jquery_34dd8afb259be3ae154887dc7db6b8a8...
# ...                                                 ...
# 3595  nwjs/nw.js_67ca76a0c8aff7be2420ba4ad75f9f8198a...
# 3596  serverless/serverless_5c44c885818107cd15ed3ebc...
# 3597  TryGhost/Ghost_6c921bf2ef554c93c6bba1fd2c1fb29...
# 3598  microsoft/TypeScript_5c951635e511aa0963ddf42f6...
# 3599  discourse/discourse_34665d3f962f1b3d16e8c75e9f...
#
#                                    commit_hash           commit_time  \
# 0     c75701a0152a589c21c4862c33b691902a8b8f7b  17/05/2006, 20:46:51
# 1     65b1081e9e9f9b8c4a0f1621c98e823eac3e6bcf  03/06/2006, 14:48:19
# 2     69ae9aeab0bae23f0fb6673d5ad58ffce44c7841  06/06/2006, 14:51:44
# 3     a457262ef5bcb163417a1f6db0b770f1fc21b3a4  11/06/2006, 03:16:36
# 4     34dd8afb259be3ae154887dc7db6b8a8fdab0b6a  16/06/2006, 02:02:54
# ...                                        ...                   ...
# 3595  67ca76a0c8aff7be2420ba4ad75f9f8198a9f430  06/11/2019, 02:55:20
# 3596  5c44c885818107cd15ed3ebcddb048f7b60d8699  07/11/2019, 10:26:04
# 3597  6c921bf2ef554c93c6bba1fd2c1fb2961dce2700  08/11/2019, 11:28:07
# 3598  5c951635e511aa0963ddf42f66d3df64e08e0533  11/11/2019, 20:24:20
# 3599  34665d3f962f1b3d16e8c75e9f8533f355d1ef7b  11/11/2019, 21:56:58
#
#                          local_repo_path  \
# 0         ../results/top_JS_repos/jquery
# 1         ../results/top_JS_repos/jquery
# 2         ../results/top_JS_repos/jquery
# 3         ../results/top_JS_repos/jquery
# 4         ../results/top_JS_repos/jquery
# ...                                  ...
# 3595       ../results/top_JS_repos/nw.js
# 3596  ../results/top_JS_repos/serverless
# 3597       ../results/top_JS_repos/Ghost
# 3598  ../results/top_JS_repos/TypeScript
# 3599   ../results/top_JS_repos/discourse
#
#                                                     url  \
# 0     https://github.com/jquery/jquery/commit/c75701...
# 1     https://github.com/jquery/jquery/commit/65b108...
# 2     https://github.com/jquery/jquery/commit/69ae9a...
# 3     https://github.com/jquery/jquery/commit/a45726...
# 4     https://github.com/jquery/jquery/commit/34dd8a...
# ...                                                 ...
# 3595  https://github.com/nwjs/nw.js/commit/67ca76a0c...
# 3596  https://github.com/serverless/serverless/commi...
# 3597  https://github.com/TryGhost/Ghost/commit/6c921...
# 3598  https://github.com/microsoft/TypeScript/commit...
# 3599  https://github.com/discourse/discourse/commit/...
#
#                                                     fix        fix_tokenType  \
# 0                            [typeof, Idf_1, !=, Lit_1]     BinaryExpression
# 1     [Idf_1, =, new, Idf_2, ., Idf_3, ., Idf_4, (, ...  ExpressionStatement
# 2                                     [Lit_1, :, Lit_2]             Property
# 3     [{, return, (, !, Idf_1, ||, Idf_1, ==, Idf_2,...       BlockStatement
# 4     [Idf_1, =, Idf_1, ||, [, Idf_2, ., Idf_3, ., I...  ExpressionStatement
# ...                                                 ...                  ...
# 3595  [!, Idf_1, ., Idf_2, (, Lit_1, ), &&, Idf_1, !...    LogicalExpression
# 3596  [return, this, ., Idf_1, [, Lit_1, ], ===, Lit...      ReturnStatement
# 3597  [Idf_1, (, Lit_1, ), ., Idf_2, (, ), ., Idf_3,...  ExpressionStatement
# 3598           [const, Idf_1, =, Idf_2, (, Lit_1, ), ;]  VariableDeclaration
# 3599                               [Idf_1, =, Lit_1, ;]  ExpressionStatement
#
#                                    fix_file_path  \
# 0                               jquery/jquery.js
# 1                                       fx/fx.js
# 2                               jquery/jquery.js
# 3                                       fx/fx.js
# 4                               jquery/jquery.js
# ...                                          ...
# 3595              src/resources/api_nw_newwin.js
# 3596     lib/plugins/aws/provider/awsProvider.js
# 3597  core/test/regression/site/frontend_spec.js
# 3598                      scripts/build/utils.js
# 3599  app/assets/javascripts/discourse-loader.js
#
#                                              fix_actual       fix_range  \
# 0                          [typeof, v, !=, 'undefined']  [14637, 14660]
# 1     [ef, =, new, $, ., fx, ., Opacity, (, this, ,,...    [1196, 1226]
# 2      ['#', :, "a.attributes['id'].nodeValue == m[2]"]    [9350, 9393]
# 3     [{, return, (, !, a, ||, a, ==, d, ||, b, ==, ...    [4595, 4621]
# 4     [data, =, data, ||, [, $, ., event, ., fix, (,...  [19793, 19840]
# ...                                                 ...             ...
# 3595  [!, key, ., endsWith, (, 'Internal', ), &&, ke...  [20806, 20850]
# 3596  [return, this, ., options, [, 'aws-s3-accelera...  [14762, 14813]
# 3597  [$, (, 'title', ), ., text, (, ), ., should, ....  [13982, 14038]
# 3598       [const, chalk, =, require, (, "chalk", ), ;]      [298, 329]
# 3599                      [name, =, "@ember/object", ;]    [6132, 6155]
#
#      fix_line                                              buggy  \
# 0     576-576                                [Idf_1, !==, Lit_2]
# 1       54-54  [Idf_1, =, new, Idf_3, ., Idf_4, (, this, ,, I...
# 2     401-401                                  [Lit_1, :, Lit_3]
# 3     176-176  [{, return, (, !, Idf_1, ||, Idf_1, ==, Idf_4,...
# 4     806-806  [Idf_1, =, Idf_1, ||, [, {, Idf_5, :, Idf_5, }...
# ...       ...                                                ...
# 3595  614-614                  [!, Idf_1, ., Idf_2, (, Lit_1, )]
# 3596  410-410     [return, !, !, this, ., Idf_1, [, Lit_3, ], ;]
# 3597  354-354  [Idf_1, (, Lit_1, ), ., Idf_2, (, ), ., Idf_3,...
# 3598    11-11  [const, {, Idf_3, :, Idf_1, }, =, Idf_2, (, Li...
# 3599  229-229                       [return, Idf_2, ., Idf_3, ;]
#
#           buggy_tokenType                             buggy_file_path  \
# 0        BinaryExpression                            jquery/jquery.js
# 1     ExpressionStatement                                    fx/fx.js
# 2                Property                            jquery/jquery.js
# 3          BlockStatement                                    fx/fx.js
# 4     ExpressionStatement                            jquery/jquery.js
# ...                   ...                                         ...
# 3595      UnaryExpression              src/resources/api_nw_newwin.js
# 3596      ReturnStatement     lib/plugins/aws/provider/awsProvider.js
# 3597  ExpressionStatement  core/test/regression/site/frontend_spec.js
# 3598  VariableDeclaration                      scripts/build/utils.js
# 3599      ReturnStatement  app/assets/javascripts/discourse-loader.js
#
#                                            buggy_actual     buggy_range  \
# 0                                        [v, !==, null]  [14637, 14647]
# 1     [ef, =, new, fx, ., Opacity, (, this, ,, o, ), ;]    [1196, 1224]
# 2              ['#', :, "a.getAttribute('id') == m[2]"]    [9350, 9385]
# 3     [{, return, (, !, a, ||, a, ==, c, ||, b, ==, ...    [4595, 4621]
# 4     [data, =, data, ||, [, {, type, :, type, }, ], ;]  [19793, 19825]
# ...                                                 ...             ...
# 3595            [!, key, ., endsWith, (, 'Internal', )]  [20806, 20831]
# 3596  [return, !, !, this, ., options, [, 'no-aws-s3...  [14762, 14808]
# 3597  [$, (, 'title', ), ., text, (, ), ., should, ....  [13982, 14036]
# 3598  [const, {, default, :, chalk, }, =, require, (...      [298, 342]
# 3599                      [return, Ember, ., Object, ;]    [6132, 6152]
#
#      buggy_line
# 0       576-576
# 1         54-54
# 2       401-401
# 3       176-176
# 4       806-806
# ...         ...
# 3595    614-614
# 3596    410-410
# 3597    354-354
# 3598      11-11
# 3599    229-229
#
# [3600 rows x 17 columns]

# %% [markdown]
# ## Generic mutation operators for branch conditions
#
# There are three sets of mutation operators. Set one is for *loop statement*, set two for *conditional statement* and
# the final set is for *return statement*. Many mutation operators for set one and two overlap. For SemSeed it
# does not matter if the mutation is made to a binary operator in a loop or a conditional. Hence we do not separate
# this. The following are the SemSeed counterparts of all mutation operators.
#
# #### 1. Change literal value in the condition

# %%
# Collect the patterns that is also seeded by mutandis
list_of_all_patterns_also_seded_by_mutandis = set()

selected_patterns = []
for _,r in single_lit_patterns.iterrows():
    pattern = r.to_dict()
    if pattern['buggy_tokenType'] == 'BinaryExpression' == pattern['fix_tokenType']:
        selected_patterns.append(pattern)
        list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 17
#                                            fix_actual  \
# 0                                 [code, ===, '(\n)']
# 1   ['linux freebsd darwin', ., indexOf, (, proces...
# 2                 [charsets, [, 0, ], ===, '.notdef']
# 3   [ev, ., type, ., toLowerCase, (, ), !=, 'touch...
# 4                  [typeof, direction, !==, 'string']
# 5   ["This project is already at ", +, releaseToPr...
# 6   ["This project is already at ", +, releaseToPr...
# 7   ['Just head back to the discussion here: http:...
# 8   ['Just head back to the discussion here: http:...
# 9       ["\t\tdefine([], ", +, amdFactory, +, ");\n"]
# 10                [config, ., entry, ., length, >, 4]
# 11  ['uppy_version_anchor: "', +, version, ., repl...
# 12  ['<p class="col-sm-4 col-xs-12">', +, data, +,...
# 13                                      [diff, -, 70]
# 14  ['EnvironmentPlugin - ', +, key, +, ' environm...
# 15  [arg, ., indexOf, (, '--override-webview-secur...
# 16                       [(, byte, &, 0x1f, ), <<, 6]
#
#                                          buggy_actual
# 0                        [code, ===, '(undefined\n)']
# 1   ['linux freebsd', ., indexOf, (, process, ., p...
# 2                [charsets, [, 0, ], ===, '.notedef']
# 3   [ev, ., type, ., toLowerCase, (, ), !=, "touch...
# 4                  [typeof, direction, !==, 'String']
# 5   ["This project is already at Meteor ", +, rele...
# 6   ["This project is already at Meteor ", +, rele...
# 7   ['Just head back to the discussion here: http:...
# 8   ['Just head back to the discussion here: http:...
# 9           ["\t\tdefine(", +, amdFactory, +, ");\n"]
# 10                [config, ., entry, ., length, >, 5]
# 11  ['uppy_version_anchor: "', +, version, ., repl...
# 12                        ['<p>', +, data, +, '</p>']
# 13                                     [diff, -, 200]
# 14  ['EnvironmentPlugin - ', +, key, +, ' environm...
# 15  [arg, ., indexOf, (, '--enable-webview-overrid...
# 16                       [(, byte, &, 0x0f, ), <<, 6]

# %% [markdown]
# Selected the following

# %%
print(selected_patterns.iloc[6,4])
print(selected_patterns.iloc[9,4])
# Out:
# https://github.com/meteor/meteor/commit/339706882b22e9f9caa667638ac93d9aa343285d
# https://github.com/webpack/webpack/commit/59656c9717c4d1b78232563d8fbe077067dd4c20

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[6,4]]
p
# Out:
#                                  file_name_where_intended  \
# 4018    benchmarks/data/geometria-lab/Beseda/benchmark...
# 12343   benchmarks/data/joshkurz/Black-Belt-AngularJS-...
# 12594   benchmarks/data/sebastienros/jint/Jint.Tests.E...
# 12955   benchmarks/data/xtuple/xtuple-server-core/task...
# 16826   benchmarks/data/jsdelivr/jsdelivr/files/spry/1...
# ...                                                   ...
# 667404       benchmarks/data/Fluidbyte/ColtJS/src/colt.js
# 667863  benchmarks/data/blackberry/BB10-WebWorks-Frame...
# 667881  benchmarks/data/sebastienros/jint/Jint.Tests.E...
# 670341  benchmarks/data/eu81273/AngularJS-RequireJS-Sa...
# 670623  benchmarks/data/opensas/BackboneBootstrap/demo...
#
#                             target_token_sequence-Correct  \
# 4018    ["Successfully stopped daemon with pid: ", +, ...
# 12343                            ["directives/", +, name]
# 12594                                      ["", +, index]
# 12955                    ["# host mappings for: ", +, id]
# 16826                                ["on", +, eventType]
# ...                                                   ...
# 667404             ["Model Sync Error: [req] : ", +, req]
# 667863                                    ["| ", +, file]
# 667881  ["#3: obj[0] = -1; obj.length = {valueOf: func...
# 670341            ["I'm the 2nd controller! ", +, tester]
# 670623                           ["order-", +, direction]
#
#                               target_token_sequence-Buggy  \
# 4018                            ["/admin/users/", +, pid]
# 12343                            ['directives/', +, name]
# 12594                                       [1, +, index]
# 12955                                       ['id', +, id]
# 16826                    ["propertychange", +, eventType]
# ...                                                   ...
# 667404                                      [404, +, req]
# 667863                                  ["file", +, file]
# 667881  ["#8.2: obj[0] = -1; obj.length = {valueOf: fu...
# 670341                                ['test', +, tester]
# 670623                        ["order-asc", +, direction]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 4018                    [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 12343                   [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 12594                   [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 12955                   [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 16826                   [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# ...                                   ...                              ...
# 667404                  [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 667863                  [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 667881                  [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 670341                  [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
# 670623                  [Lit_1, +, Idf_1]                [Lit_2, +, Idf_1]
#
#                                    target_line_range  \
# 4018          {'line': '20-20', 'range': [536, 582]}
# 12343     {'line': '172-172', 'range': [5170, 5188]}
# 12594           {'line': '5-5', 'range': [186, 196]}
# 12955         {'line': '10-10', 'range': [449, 477]}
# 16826   {'line': '378-378', 'range': [18924, 18940]}
# ...                                              ...
# 667404  {'line': '325-325', 'range': [13526, 13560]}
# 667863      {'line': '36-36', 'range': [1073, 1084]}
# 667881        {'line': '37-37', 'range': [812, 948]}
# 670341          {'line': '5-5', 'range': [159, 194]}
# 670623      {'line': '59-59', 'range': [2744, 2764]}
#
#         num_of_available_identifiers_to_choose_from  \
# 4018                                           1010
# 12343                                          1055
# 12594                                          1005
# 12955                                          1008
# 16826                                          1106
# ...                                             ...
# 667404                                         1092
# 667863                                         1021
# 667881                                         1001
# 670341                                         1005
# 670623                                         1025
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 4018                                        1018  False           0.4540
# 12343                                       1057  False           0.3520
# 12594                                       1005  False           0.3115
# 12955                                       1007  False           0.3735
# 16826                                       1044  False           0.3030
# ...                                          ...    ...              ...
# 667404                                      1039  False           0.4060
# 667863                                      1029  False           0.3275
# 667881                                      1012  False           0.3685
# 670341                                      1003  False           0.3295
# 670623                                      1027  False           0.3220
#
#                                       seeding_pattern_url
# 4018    https://github.com/meteor/meteor/commit/339706...
# 12343   https://github.com/meteor/meteor/commit/339706...
# 12594   https://github.com/meteor/meteor/commit/339706...
# 12955   https://github.com/meteor/meteor/commit/339706...
# 16826   https://github.com/meteor/meteor/commit/339706...
# ...                                                   ...
# 667404  https://github.com/meteor/meteor/commit/339706...
# 667863  https://github.com/meteor/meteor/commit/339706...
# 667881  https://github.com/meteor/meteor/commit/339706...
# 670341  https://github.com/meteor/meteor/commit/339706...
# 670623  https://github.com/meteor/meteor/commit/339706...
#
# [324 rows x 11 columns]

# %% [markdown]
# #### 2. Replace relational operators

# %%
relational_operators = {'<', '>', '<=', '>=', '==', '!=', '===', '!=='}
selected_patterns = []
for _,r in single_operator_patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    if pattern['buggy_tokenType'] == 'BinaryExpression' == pattern['fix_tokenType']:
        for t in pattern['fix']:
            if 'Lit_' not in t and 'Idf_' not in t:
                f.append(t)
        for t in pattern['buggy']:
            if 'Lit_' not in t and 'Idf_' not in t:
                b.append(t)
        
        if len(f) == 1 == len(b) and f != b and relational_operators.intersection(set(f)) and relational_operators.intersection(set(b)):
            list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
            selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 11
#                     fix_actual                buggy_actual
# 0          [start, <=, cursor]          [start, <, cursor]
# 1    [newIndex, !==, oldIndex]    [newIndex, !=, oldIndex]
# 2     [newIndex, !=, oldIndex]   [newIndex, !==, oldIndex]
# 3          [strCounter, >=, 0]          [strCounter, >, 0]
# 4              [n, !==, title]              [n, !=, title]
# 5                    [i, >, 0]                  [i, >=, 0]
# 6          [influence, !==, 0]           [influence, >, 0]
# 7                  [det, >, 0]                [det, >=, 0]
# 8              [offset, >=, 0]              [offset, >, 0]
# 9   [shaderID, !==, undefined]  [shaderID, ===, undefined]
# 10         [i, !==, startLine]          [i, !=, startLine]

# %% [markdown]
# Selected the following

# %%
print(selected_patterns.iloc[4,4])
print(selected_patterns.iloc[5,4])
# Out:
# https://github.com/discourse/discourse/commit/1dd6699bf22d9a3f387fee36a1b46671c284d9ce
# https://github.com/adobe/brackets/commit/30d50a59efd095b3788bad4d19c5c827c115fe67

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]].sample(5)
p
# Out:
#                                  file_name_where_intended  \
# 517979  benchmarks/data/sebastienros/jint/Jint.Tests.E...
# 560247  benchmarks/data/acumenbrands/rest_suite/lib/ne...
# 234826  benchmarks/data/qooxdoo/qooxdoo/framework/sour...
# 422921  benchmarks/data/jstacoder/flask-ide/flask_ide/...
# 99076   benchmarks/data/sebastienros/jint/Jint.Tests.E...
#
#        target_token_sequence-Correct target_token_sequence-Buggy  \
# 517979          [index_n, <=, index]         [index_n, <, index]
# 560247            [index, <=, count]           [index, <, count]
# 234826                  [i, <=, max]                 [i, <, max]
# 422921                [cur, <=, end]               [cur, <, end]
# 99076           [index_n, <=, index]         [index_n, <, index]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 517979                 [Idf_1, <=, Idf_2]                [Idf_1, <, Idf_2]
# 560247                 [Idf_1, <=, Idf_2]                [Idf_1, <, Idf_2]
# 234826                 [Idf_1, <=, Idf_2]                [Idf_1, <, Idf_2]
# 422921                 [Idf_1, <=, Idf_2]                [Idf_1, <, Idf_2]
# 99076                  [Idf_1, <=, Idf_2]                [Idf_1, <, Idf_2]
#
#                                  target_line_range  \
# 517979      {'line': '13-13', 'range': [416, 432]}
# 560247  {'line': '152-152', 'range': [6346, 6360]}
# 234826    {'line': '27-27', 'range': [1037, 1045]}
# 422921    {'line': '35-35', 'range': [1485, 1495]}
# 99076       {'line': '23-23', 'range': [733, 749]}
#
#         num_of_available_identifiers_to_choose_from  \
# 517979                                         1005
# 560247                                         1076
# 234826                                         1045
# 422921                                         1021
# 99076                                          1005
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 517979                                      1005  False           0.3535
# 560247                                      1010  False           0.4500
# 234826                                      1003  False           0.3725
# 422921                                      1004  False           0.3455
# 99076                                       1005  False           0.3535
#
#                                       seeding_pattern_url
# 517979  https://github.com/adobe/brackets/commit/cdf9d...
# 560247  https://github.com/adobe/brackets/commit/cdf9d...
# 234826  https://github.com/adobe/brackets/commit/cdf9d...
# 422921  https://github.com/adobe/brackets/commit/cdf9d...
# 99076   https://github.com/adobe/brackets/commit/cdf9d...

# %% [markdown]
# #### 3. Replace logical operators

# %%
logical_operators = {'&&', '||'}
selected_patterns = []
for _,r in single_operator_patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    if pattern['buggy_tokenType'] == 'LogicalExpression' == pattern['fix_tokenType']:
        for t in pattern['fix']:
            if 'Lit_' not in t and 'Idf_' not in t:
                f.append(t)
        for t in pattern['buggy']:
            if 'Lit_' not in t and 'Idf_' not in t:
                b.append(t)
        f_lops = logical_operators.intersection(set(f))
        b_lops = logical_operators.intersection(set(b))

        if  f != b and f_lops and b_lops and f_lops != b_lops :
            selected_patterns.append(pattern)
            list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 4
#                                           fix_actual  \
# 0  [err, ., code, !==, 134, &&, err, ., signal, !...
# 1                  [!, token, ||, !, token, [, 1, ]]
# 2             [!, offset, ., x, &&, !, offset, ., y]
# 3  [pose, ., angularVelocity, !==, null, &&, !, a...
#
#                                         buggy_actual
# 0  [err, ., code, !==, 134, ||, err, ., signal, !...
# 1                  [!, token, &&, !, token, [, 1, ]]
# 2             [!, offset, ., x, ||, !, offset, ., y]
# 3  [pose, ., angularVelocity, !==, null, ||, !, a...

# %% [markdown]
# Selected the following
#
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[2,4]]
p
# Out:
#                                  file_name_where_intended  \
# 654442  benchmarks/data/cdnjs/cdnjs/ajax/libs/custom-e...
#
#                          target_token_sequence-Correct  \
# 654442  [!, property, ., set, &&, !, property, ., get]
#
#                            target_token_sequence-Buggy  \
# 654442  [!, property, ., set, ||, !, property, ., get]
#
#                   token_sequence_abstraction-Correct  \
# 654442  [!, Idf_1, ., Idf_2, &&, !, Idf_1, ., Idf_3]
#
#                     token_sequence_abstraction-Buggy  \
# 654442  [!, Idf_1, ., Idf_2, ||, !, Idf_1, ., Idf_3]
#
#                                  target_line_range  \
# 654442  {'line': '158-158', 'range': [5838, 5868]}
#
#         num_of_available_identifiers_to_choose_from  \
# 654442                                         1083
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 654442                                      1011  False            0.314
#
#                                       seeding_pattern_url
# 654442  https://github.com/Leaflet/Leaflet/commit/c4b6...

# %% [markdown]
# #### 4. Swap consecutive nested for/while
#
# We can't have this pattern since we look for single line changes

# %% [markdown]
# #### 5. Replace arithmetic operators

# %%
arithmetic_operators = {'+' '-' '/' '*' '%' '**', '+=', '-='}
selected_patterns = []
for _,r in single_operator_patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    # if pattern['buggy_tokenType'] == 'LogicalExpression' == pattern['fix_tokenType']:
    for t in pattern['fix']:
        if 'Lit_' not in t and 'Idf_' not in t:
            f.append(t)
    for t in pattern['buggy']:
        if 'Lit_' not in t and 'Idf_' not in t:
            b.append(t)
    f_lops = arithmetic_operators.intersection(set(f))
    b_lops = arithmetic_operators.intersection(set(b))

    if  f != b and f_lops and b_lops and f_lops != b_lops :
        list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
        selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 1
#                         fix_actual                     buggy_actual
# 0  [minutes, -=, offsetMinutes, ;]  [minutes, +=, offsetMinutes, ;]

# %% [markdown]
# Selected the following

# %%
print(selected_patterns.iloc[0, 4])
# Out:
# https://github.com/mozilla/pdf.js/commit/4acb744f77a3828efdd26d08f6ffd9517302b3a8
# https://github.com/photonstorm/phaser/commit/b48c2a8173b357b391aa4c16ccbfa3346dd9038f

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]]
p
# Out:
#                                  file_name_where_intended  \
# 163860  benchmarks/data/chadn/heroku-sails/node_module...
# 443032  benchmarks/data/tcorral/Refactoring_Patterns/1...
# 612263  benchmarks/data/mdipierro/web2py-appliances/Sy...
#
#              target_token_sequence-Correct  \
# 163860         [end, -=, lenIncomplete, ;]
# 443032  [nSubTotal, -=, nDiscountValue, ;]
# 612263             [cpt_last, -=, step, ;]
#
#                target_token_sequence-Buggy token_sequence_abstraction-Correct  \
# 163860         [end, +=, lenIncomplete, ;]              [Idf_1, -=, Idf_2, ;]
# 443032  [nSubTotal, +=, nDiscountValue, ;]              [Idf_1, -=, Idf_2, ;]
# 612263             [cpt_last, +=, step, ;]              [Idf_1, -=, Idf_2, ;]
#
#        token_sequence_abstraction-Buggy  \
# 163860            [Idf_1, +=, Idf_2, ;]
# 443032            [Idf_1, +=, Idf_2, ;]
# 612263            [Idf_1, +=, Idf_2, ;]
#
#                                  target_line_range  \
# 163860    {'line': '52-52', 'range': [1918, 1939]}
# 443032      {'line': '17-17', 'range': [615, 643]}
# 612263  {'line': '100-100', 'range': [5084, 5101]}
#
#         num_of_available_identifiers_to_choose_from  \
# 163860                                         1015
# 443032                                         1012
# 612263                                         1071
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 163860                                      1006  False           0.3625
# 443032                                      1001  False           0.3375
# 612263                                      1045  False           0.3495
#
#                                       seeding_pattern_url
# 163860  https://github.com/mozilla/pdf.js/commit/4acb7...
# 443032  https://github.com/mozilla/pdf.js/commit/4acb7...
# 612263  https://github.com/mozilla/pdf.js/commit/4acb7...

# %% [markdown]
# #### 6. Replace x++/x-- with ++x/--x
# **Note:** Could not find an instance where this happens

# %%
UpdateOperator = {'++', '--'}
selected_patterns = []
for _,r in single_operator_patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    # if pattern['buggy_tokenType'] == 'LogicalExpression' == pattern['fix_tokenType']:
    for t in pattern['fix']:
        if 'Lit_' not in t and 'Idf_' not in t:
            f.append(t)
    for t in pattern['buggy']:
        if 'Lit_' not in t and 'Idf_' not in t:
            b.append(t)
    f_lops = UpdateOperator.intersection(set(f))
    b_lops = UpdateOperator.intersection(set(b))

    if  f != b and f_lops and b_lops and f_lops != b_lops :
        selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
if len(selected_patterns):
    selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 0

# %% [markdown]
# #### 7. Remove 'break'/'continue'
#
# **Note:** Could not find removing the statements. We could only find instances where either of these
# statements has been replaced with another.

# %%
selected_patterns = []
toks = ['break', 'continue']
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    for t in pattern['fix']:
        if 'Lit_' not in t and 'Idf_' not in t:
            f.append(t)
    for t in pattern['buggy']:
        if 'Lit_' not in t and 'Idf_' not in t:
            b.append(t)
    for op in toks:

        if op in f and op not in b:
            if pattern['url'] not in seen_url:
                seen_url.add(pattern['url'])
                selected_patterns.append(pattern)
        if op not in f and op in b:
            if pattern['url'] not in seen_url:
                seen_url.add(pattern['url'])
                selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 1
#                                           fix_actual  \
# 0  [if, (, !, module, ., chunkCondition, ), conti...
#
#                                         buggy_actual
# 0  [if, (, !, module, ., chunkCondition, ), retur...

# %% [markdown]
# Selected the following

# %%
print(selected_patterns.iloc[0,4])
# print(selected_patterns.iloc[1,4])
# Out:
# https://github.com/webpack/webpack/commit/114abeeb4d1023b3da8f5ac22686c83ff78356a7

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]]
p
# Out:
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []

# %% [markdown]
# #### 8. Replace 0/1 with false/true and vice-versa in the condition

# %%
selected_patterns = []
toks = ['0', '1']
rep_toks = ['false', 'true']
seen_url = set()
for _,r in single_lit_patterns.iterrows():
    pattern = r.to_dict()
    for idx, tk in enumerate(toks):
        if tk in pattern['fix_actual'] and rep_toks[idx] in pattern['buggy_actual']:
            if pattern['url'] not in seen_url:
                seen_url.add(pattern['url'])
                list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
                selected_patterns.append(pattern)
        if rep_toks[idx] in pattern['fix_actual'] and tk in pattern['buggy_actual']:
                    if pattern['url'] not in seen_url:
                        seen_url.add(pattern['url'])
                        list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
                        selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 4
#                                           fix_actual  \
# 0                              [timerId, =, true, ;]
# 1  [equals, (, obj, ., contains, (, data, [, 0, ]...
# 2  [EI, :, {, fnName, :, 'endInlineImage', ,, num...
# 3  [{, model, :, Label, ,, required, :, false, ,,...
#
#                                         buggy_actual
# 0                                 [timerId, =, 1, ;]
# 1  [equals, (, obj, ., contains, (, data, [, 0, ]...
# 2  [EI, :, {, fnName, :, 'endInlineImage', ,, num...
# 3  [{, model, :, Label, ,, required, :, false, ,,...

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]]
p
# Out:
#                                  file_name_where_intended  \
# 65      benchmarks/data/xinyu198736/htmljs/assets/js/p...
# 349     benchmarks/data/yetone/collipa/collipa/static/...
# 3318    benchmarks/data/kandanapp/kandan/app/assets/ja...
# 5220      benchmarks/data/micheleg/dash-to-dock/myDash.js
# 5913    benchmarks/data/yathit/ydn-db/test/crud/list_t...
# ...                                                   ...
# 670182  benchmarks/data/ASTPP/ASTPP/web_interface/astp...
# 672416                 benchmarks/data/atesh/XKit/xkit.js
# 673733     benchmarks/data/jonschlinkert/engines/index.js
# 673863  benchmarks/data/OpenAcademy/HTML5-open-academy...
# 676893             benchmarks/data/garyv/srcery/srcery.js
#
#               target_token_sequence-Correct       target_token_sequence-Buggy  \
# 65                        [PCAAV, =, "", ;]                  [PCAAV, =, 1, ;]
# 349                         [a, =, true, ;]                      [a, =, 1, ;]
# 3318                  [element, =, null, ;]                [element, =, 1, ;]
# 5220                         [pos, =, 0, ;]                    [pos, =, 1, ;]
# 5913                 [get_done, =, true, ;]               [get_done, =, 1, ;]
# ...                                     ...                               ...
# 670182                       [val, =, 0, ;]                    [val, =, 1, ;]
# 672416  [conflicting_extension, =, true, ;]  [conflicting_extension, =, 1, ;]
# 673733                   [done, =, true, ;]                   [done, =, 1, ;]
# 673863               [inEditor, =, true, ;]               [inEditor, =, 1, ;]
# 676893                   [vHeight, =, 0, ;]                [vHeight, =, 1, ;]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 65                   [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 349                  [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 3318                 [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 5220                 [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 5913                 [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# ...                                   ...                              ...
# 670182               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 672416               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 673733               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 673863               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 676893               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
#
#                                    target_line_range  \
# 65        {'line': '68-68', 'range': [18839, 18850]}
# 349     {'line': '938-938', 'range': [41875, 41884]}
# 3318        {'line': '77-77', 'range': [3207, 3222]}
# 5220    {'line': '714-714', 'range': [32244, 32252]}
# 5913      {'line': '154-154', 'range': [3930, 3946]}
# ...                                              ...
# 670182      {'line': '44-44', 'range': [1750, 1758]}
# 672416  {'line': '695-695', 'range': [33128, 33157]}
# 673733      {'line': '71-71', 'range': [1812, 1824]}
# 673863      {'line': '51-51', 'range': [1878, 1894]}
# 676893    {'line': '101-101', 'range': [3610, 3622]}
#
#         num_of_available_identifiers_to_choose_from  \
# 65                                             1034
# 349                                            1323
# 3318                                           1083
# 5220                                           1466
# 5913                                           1057
# ...                                             ...
# 670182                                         1018
# 672416                                         1170
# 673733                                         1053
# 673863                                         1040
# 676893                                         1031
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 65                                          1006  False           0.3625
# 349                                         1307  False           0.5145
# 3318                                        1054  False           0.4090
# 5220                                        1066  False           0.4185
# 5913                                        1034  False           0.6450
# ...                                          ...    ...              ...
# 670182                                      1012  False           0.3530
# 672416                                      1247  False           0.6160
# 673733                                      1032  False           0.6270
# 673863                                      1035  False           0.6185
# 676893                                      1012  False           0.4135
#
#                                       seeding_pattern_url
# 65      https://github.com/jquery/jquery/commit/ab1504...
# 349     https://github.com/jquery/jquery/commit/ab1504...
# 3318    https://github.com/jquery/jquery/commit/ab1504...
# 5220    https://github.com/jquery/jquery/commit/ab1504...
# 5913    https://github.com/jquery/jquery/commit/ab1504...
# ...                                                   ...
# 670182  https://github.com/jquery/jquery/commit/ab1504...
# 672416  https://github.com/jquery/jquery/commit/ab1504...
# 673733  https://github.com/jquery/jquery/commit/ab1504...
# 673863  https://github.com/jquery/jquery/commit/ab1504...
# 676893  https://github.com/jquery/jquery/commit/ab1504...
#
# [382 rows x 11 columns]

# %% [markdown]
# #### 9. Remove return
# Not possible in our pattern

# %%
selected_patterns = []
tk = 'return'
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    copy_patter = list(pattern['fix_actual'])
    if tk in pattern['fix_actual'] and tk not in pattern['buggy_actual']:
        copy_patter.remove(tk)
        if pattern['buggy_actual'] == copy_patter:
            list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
            selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 13
#                                            fix_actual  \
# 0   [return, f, ., apply, (, this, ,, arguments, )...
# 1           [if, (, err, ), return, cb, (, err, ), ;]
# 2   [return, defaultFocus, ., apply, (, this, ,, a...
# 3   [return, local_moment, ., apply, (, null, ,, a...
# 4                    [return, callback, (, err, ), ;]
# 5   [return, ParanoidUser, ., bulkCreate, (, data, )]
# 6      [return, del, (, paths, ., out, ,, done, ), ;]
# 7   [return, this, ., _imap, ., serverSupports, (,...
# 8     [if, (, db, ==, null, ), return, resolve, (, )]
# 9   [return, this, ., play, (, null, ,, 0, ,, volu...
# 10  [return, transactionSource, ., flatMap, (, (, ...
# 11  [return, this, ., add, (, child, ,, silent, ,,...
# 12  [return, _, ., omit, (, this, ,, 'settings', )...
#
#                                          buggy_actual
# 0          [f, ., apply, (, this, ,, arguments, ), ;]
# 1                   [if, (, err, ), cb, (, err, ), ;]
# 2   [defaultFocus, ., apply, (, this, ,, arguments...
# 3   [local_moment, ., apply, (, null, ,, arguments...
# 4                            [callback, (, err, ), ;]
# 5           [ParanoidUser, ., bulkCreate, (, data, )]
# 6              [del, (, paths, ., out, ,, done, ), ;]
# 7   [this, ., _imap, ., serverSupports, (, capabil...
# 8             [if, (, db, ==, null, ), resolve, (, )]
# 9   [this, ., play, (, null, ,, 0, ,, volume, ,, t...
# 10  [transactionSource, ., flatMap, (, (, t, ), =>...
# 11  [this, ., add, (, child, ,, silent, ,, index, ...
# 12         [_, ., omit, (, this, ,, 'settings', ), ;]

# %%
print(selected_patterns.iloc[0,4])
print(selected_patterns.iloc[5,4])
# Out:
# https://github.com/jquery/jquery/commit/a8bafe78745247dd13e3472582df29471e50aa28
# https://github.com/sequelize/sequelize/commit/95d5ebac6eb0ebda411218c47e6db33cd210f005

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[4,4]]
p
# Out:
#                                  file_name_where_intended  \
# 4150    benchmarks/data/jxcore/jxcore/deps/v8/test/mjs...
# 4788    benchmarks/data/joola/joola/test/unit/99_REST/...
# 10298   benchmarks/data/joola/joola/test/unit/99_REST/...
# 17665   benchmarks/data/jsbin/jsbin/lib/handlers/sessi...
# 19188   benchmarks/data/jsbin/jsbin/lib/handlers/sessi...
# ...                                                   ...
# 635297  benchmarks/data/mozilla/node-convict/test/stat...
# 641197  benchmarks/data/hectorcorrea/hectorcorrea.com/...
# 645877  benchmarks/data/petkaantonov/bluebird/test/moc...
# 659675  benchmarks/data/hectorcorrea/hectorcorrea.com/...
# 660532  benchmarks/data/tonistiigi/styler/lib/public/l...
#
#               target_token_sequence-Correct  target_token_sequence-Buggy  \
# 4150         [return, Number, (, val, ), ;]       [Number, (, val, ), ;]
# 4788           [return, done, (, err, ), ;]         [done, (, err, ), ;]
# 10298          [return, done, (, err, ), ;]         [done, (, err, ), ;]
# 17665          [return, next, (, err, ), ;]         [next, (, err, ), ;]
# 19188          [return, next, (, err, ), ;]         [next, (, err, ), ;]
# ...                                     ...                          ...
# 635297           [return, done, (, e, ), ;]           [done, (, e, ), ;]
# 641197     [return, callback, (, err, ), ;]     [callback, (, err, ), ;]
# 645877  [return, clearTimeout, (, id, ), ;]  [clearTimeout, (, id, ), ;]
# 659675     [return, callback, (, err, ), ;]     [callback, (, err, ), ;]
# 660532      [return, stopEvent, (, e, ), ;]      [stopEvent, (, e, ), ;]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 4150      [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 4788      [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 10298     [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 17665     [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 19188     [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# ...                                   ...                              ...
# 635297    [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 641197    [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 645877    [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 659675    [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
# 660532    [return, Idf_1, (, Idf_2, ), ;]          [Idf_1, (, Idf_2, ), ;]
#
#                                    target_line_range  \
# 4150              {'line': '2-2', 'range': [29, 48]}
# 4788        {'line': '95-95', 'range': [3447, 3464]}
# 10298         {'line': '20-20', 'range': [645, 662]}
# 17665       {'line': '53-53', 'range': [1808, 1825]}
# 19188         {'line': '23-23', 'range': [875, 892]}
# ...                                              ...
# 635297      {'line': '60-60', 'range': [1884, 1899]}
# 641197    {'line': '127-127', 'range': [3973, 3994]}
# 645877      {'line': '50-50', 'range': [2154, 2178]}
# 659675    {'line': '131-131', 'range': [4253, 4274]}
# 660532  {'line': '249-249', 'range': [11046, 11066]}
#
#         num_of_available_identifiers_to_choose_from  \
# 4150                                           1005
# 4788                                           1019
# 10298                                          1019
# 17665                                          1098
# 19188                                          1098
# ...                                             ...
# 635297                                         1013
# 641197                                         1024
# 645877                                         1023
# 659675                                         1024
# 660532                                         1059
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 4150                                        1143  False           0.3075
# 4788                                        1028  False           0.8090
# 10298                                       1028  False           0.8090
# 17665                                       1060  False           0.7515
# 19188                                       1060  False           0.7515
# ...                                          ...    ...              ...
# 635297                                      1010  False           0.5325
# 641197                                      1019  False           1.0000
# 645877                                      1022  False           0.4040
# 659675                                      1019  False           1.0000
# 660532                                      1037  False           0.3820
#
#                                       seeding_pattern_url
# 4150    https://github.com/webpack/webpack/commit/6085...
# 4788    https://github.com/webpack/webpack/commit/6085...
# 10298   https://github.com/webpack/webpack/commit/6085...
# 17665   https://github.com/webpack/webpack/commit/6085...
# 19188   https://github.com/webpack/webpack/commit/6085...
# ...                                                   ...
# 635297  https://github.com/webpack/webpack/commit/6085...
# 641197  https://github.com/webpack/webpack/commit/6085...
# 645877  https://github.com/webpack/webpack/commit/6085...
# 659675  https://github.com/webpack/webpack/commit/6085...
# 660532  https://github.com/webpack/webpack/commit/6085...
#
# [69 rows x 11 columns]

# %% [markdown]
# #### 10. Replace return true with return false and vice versa

# %%
selected_patterns = []
toks = ['returntrue', 'returnfalse']
rep_toks = ['returnfalse', 'returntrue']
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    for idx, tk in enumerate(toks):
        if tk in ''.join(pattern['fix_actual']) and rep_toks[idx] in ''.join(pattern['buggy_actual']):
            if pattern['url'] not in seen_url:
                seen_url.add(pattern['url'])
                list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
                selected_patterns.append(pattern)
        if rep_toks[idx] in ''.join(pattern['fix_actual']) and tk in ''.join(pattern['buggy_actual']):
                    if pattern['url'] not in seen_url:
                        seen_url.add(pattern['url'])
                        list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
                        selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 4
#                                           fix_actual  \
# 0                                 [return, false, ;]
# 1                                  [return, true, ;]
# 2  [sandbox, ., stub, (, ghost, ., mail, ,, 'isWi...
# 3                                  [return, true, ;]
#
#                                         buggy_actual
# 0                                  [return, true, ;]
# 1                                 [return, false, ;]
# 2  [sandbox, ., stub, (, ghost, ., mail, ,, 'isWi...
# 3                                 [return, false, ;]

# %% [markdown]
# selected the following

# %%
print(selected_patterns.iloc[0, 4])
print(selected_patterns.iloc[1, 4])
# Out:
# https://github.com/emberjs/ember.js/commit/7aaf128c0098d020ccf67e16642dccddb937bdef
# https://github.com/lodash/lodash/commit/a2a71a107e2aa5cfb7ab9cfa8c10b41885334160

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]].sample(5)
p
# Out:
#                                  file_name_where_intended  \
# 22128   benchmarks/data/tinyspeck/glitch-GameServerJS/...
# 183488  benchmarks/data/Galloman/ss2d/ss2d.js/src/scen...
# 305365  benchmarks/data/cloudkick/cast/lib/plugins/man...
# 219678  benchmarks/data/documentcloud/visualsearch/bui...
# 516299  benchmarks/data/cdnjs/cdnjs/ajax/libs/dojo/1.1...
#
#        target_token_sequence-Correct target_token_sequence-Buggy  \
# 22128             [return, false, ;]           [return, true, ;]
# 183488             [return, null, ;]           [return, true, ;]
# 305365             [return, true, ;]          [return, false, ;]
# 219678            [return, false, ;]           [return, true, ;]
# 516299            [return, false, ;]           [return, true, ;]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 22128                  [return, Lit_1, ;]               [return, Lit_2, ;]
# 183488                 [return, Lit_1, ;]               [return, Lit_2, ;]
# 305365                 [return, Lit_1, ;]               [return, Lit_2, ;]
# 219678                 [return, Lit_1, ;]               [return, Lit_2, ;]
# 516299                 [return, Lit_1, ;]               [return, Lit_2, ;]
#
#                                      target_line_range  \
# 22128       {'line': '129-129', 'range': [3791, 3804]}
# 183488        {'line': '99-99', 'range': [3616, 3628]}
# 305365      {'line': '138-138', 'range': [5512, 5524]}
# 219678  {'line': '1083-1083', 'range': [43455, 43468]}
# 516299        {'line': '63-63', 'range': [2657, 2670]}
#
#         num_of_available_identifiers_to_choose_from  \
# 22128                                          1224
# 183488                                         1113
# 305365                                         1093
# 219678                                         1215
# 516299                                         1085
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 22128                                       1324  False            1.000
# 183488                                      1032  False            0.732
# 305365                                      1034  False            0.928
# 219678                                      1191  False            1.000
# 516299                                      1039  False            1.000
#
#                                       seeding_pattern_url
# 22128   https://github.com/emberjs/ember.js/commit/7aa...
# 183488  https://github.com/emberjs/ember.js/commit/7aa...
# 305365  https://github.com/emberjs/ember.js/commit/7aa...
# 219678  https://github.com/emberjs/ember.js/commit/7aa...
# 516299  https://github.com/emberjs/ember.js/commit/7aa...

# %% [markdown]
# ## JavaScript-Specific Mutation Operators
#
# #### 1. Adding/Removing the var keyword

# %%
selected_patterns = []
toks = ['var']
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    for t in pattern['fix']:
        if 'Lit_' not in t and 'Idf_' not in t:
            f.append(t)
    for t in pattern['buggy']:
        if 'Lit_' not in t and 'Idf_' not in t:
            b.append(t)
    for op in toks:
        di_f_b = len(set(f)-set(b)) == 1
        di_b_f = len(set(b)-set(f)) == 1

        if op in f and op not in b:
            if pattern['url'] not in seen_url:
                seen_url.add(pattern['url'])
                if 'const' not in pattern['buggy_actual']:
                    list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
                    selected_patterns.append(pattern)
        if op not in f and op in b:
            if pattern['url'] not in seen_url:
                seen_url.add(pattern['url'])
                if 'let' not in pattern['fix_actual']:
                    list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
                    selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 24
#                                            fix_actual  \
# 0             [var, i, =, 0, ,, l, =, not, ., length]
# 1   [var, filter, =, style, ., filter, ||, jQuery,...
# 2   [var, match, =, jQuery, ., noData, [, elem, .,...
# 3           [var, encoding, =, arguments, [, 3, ], ;]
# 4   [var, stats, =, fs, ., statSync, (, requestPat...
# 5        [candidateInfluence, =, influences, [, i, ]]
# 6   [var, envDialect, =, process, ., env, ., DIALE...
# 7   [var, appView, =, Discourse, ., __container__,...
# 8    [var, promise, =, new, Em, ., Deferred, (, ), ;]
# 9                [var, opts, =, options, ||, {, }, ;]
# 10  [$, (, element, ), ., on, (, 'click.bs.dropdow...
# 11       [var, o, =, 0, ,, ol, =, offsets, ., length]
# 12      [var, v, =, 1, ,, vl, =, vertices, ., length]
# 13                          [var, result, =, true, ;]
# 14  [NativeModule, ., require, (, 'timers', ), ., ...
# 15  [NativeModule, ., require, (, 'timers', ), ., ...
# 16           [var, run, =, s, ., run, (, "run", ), ;]
# 17  [(, navigator, ., appVersion, ), ., match, (, ...
# 18          [bound, =, d, ., intercept, (, fn2, ), ;]
# 19                                 [objectA, =, {, }]
# 20       [var, should, =, require, (, "should", ), ;]
# 21  [var, triangleNode, =, triangleNodes, [, i, ], ;]
# 22              [var, lStack, =, (, ++, _stack, ), ;]
# 23                  [var, msg, =, `${, prefix, }`, ;]
#
#                                          buggy_actual
# 0                  [i, =, 0, ,, l, =, not, ., length]
# 1   [filter, =, style, ., filter, ||, jQuery, ., c...
# 2   [match, =, jQuery, ., noData, [, elem, ., node...
# 3                [encoding, =, arguments, [, 3, ], ;]
# 4   [stats, =, fs, ., statSync, (, requestPath, ), ;]
# 5   [var, candidateInfluence, =, influences, [, i, ]]
# 6   [envDialect, =, process, ., env, ., DIALECT, |...
# 7   [appView, =, Discourse, ., __container__, ., l...
# 8         [promise, =, new, Em, ., Deferred, (, ), ;]
# 9                     [opts, =, options, ||, {, }, ;]
# 10  [var, $el, =, $, (, element, ), ., on, (, 'cli...
# 11            [o, =, 0, ,, ol, =, offsets, ., length]
# 12           [v, =, 1, ,, vl, =, vertices, ., length]
# 13                               [result, =, true, ;]
# 14  [var, t, =, setImmediate, (, process, ., _tick...
# 15  [var, t, =, setImmediate, (, process, ., _tick...
# 16                [run, =, s, ., run, (, "run", ), ;]
# 17  [var, v, =, (, navigator, ., appVersion, ), .,...
# 18     [var, bound, =, d, ., intercept, (, fn2, ), ;]
# 19                            [var, objectA, =, {, }]
# 20              [ould, =, require, (, "should", ), ;]
# 21       [triangleNode, =, triangleNodes, [, i, ], ;]
# 22                   [lStack, =, (, ++, _stack, ), ;]
# 23                  [let, msg, =, `${, prefix, }`, ;]

# %% [markdown]
# Selected the following

# %%
print(selected_patterns.iloc[13,4])
print(selected_patterns.iloc[28,4])
# Out:
# https://github.com/Reactive-Extensions/RxJS/commit/d3e10f70cca7c7a32d765cc91877f503a10b47ca
# https://github.com/alvarotrigo/fullPage.js/commit/bd1bc752c4520508f6be646b6889b0c34a30d17f

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[19,4]].sample(5).sort_values(by='mean_similarity')
p
# Out:
#                                  file_name_where_intended  \
# 354207  benchmarks/data/iamtrk/twitterArchitectureClon...
# 641345  benchmarks/data/cdnjs/cdnjs/ajax/libs/topojson...
# 671532  benchmarks/data/Akihabara/akihabara/src/akihab...
# 262743  benchmarks/data/WebAppSolutionInc/sencha-cafe-...
# 350673       benchmarks/data/Fluidbyte/ColtJS/src/colt.js
#
#        target_token_sequence-Correct target_token_sequence-Buggy  \
# 354207                [map, =, {, }]         [var, map, =, {, }]
# 641345          [arcsByEnd, =, {, }]   [var, arcsByEnd, =, {, }]
# 671532               [data, =, {, }]        [var, data, =, {, }]
# 262743           [dispatch, =, {, }]    [var, dispatch, =, {, }]
# 350673            [request, =, {, }]     [var, request, =, {, }]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 354207                   [Idf_1, =, {, }]            [var, Idf_1, =, {, }]
# 641345                   [Idf_1, =, {, }]            [var, Idf_1, =, {, }]
# 671532                   [Idf_1, =, {, }]            [var, Idf_1, =, {, }]
# 262743                   [Idf_1, =, {, }]            [var, Idf_1, =, {, }]
# 350673                   [Idf_1, =, {, }]            [var, Idf_1, =, {, }]
#
#                                    target_line_range  \
# 354207    {'line': '137-137', 'range': [4839, 4847]}
# 641345            {'line': '3-3', 'range': [73, 87]}
# 671532        {'line': '18-18', 'range': [434, 443]}
# 262743      {'line': '74-74', 'range': [2851, 2864]}
# 350673  {'line': '350-350', 'range': [14403, 14415]}
#
#         num_of_available_identifiers_to_choose_from  \
# 354207                                         1036
# 641345                                         1047
# 671532                                         1075
# 262743                                         1027
# 350673                                         1092
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 354207                                      1024  False            0.308
# 641345                                      1004  False            0.319
# 671532                                      1026  False            0.327
# 262743                                      1007  False            0.329
# 350673                                      1039  False            0.345
#
#                                       seeding_pattern_url
# 354207  https://github.com/electron/electron/commit/bd...
# 641345  https://github.com/electron/electron/commit/bd...
# 671532  https://github.com/electron/electron/commit/bd...
# 262743  https://github.com/electron/electron/commit/bd...
# 350673  https://github.com/electron/electron/commit/bd...

# %% [markdown]
# #### 2. Remove global search flag from replace
# **Not found**

# %%
selected_patterns = []
toks = ['replace']
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    for idx,t in enumerate(pattern['fix']):
        if 'Idf_' in t:
            f.append(pattern['fix_actual'][idx])
    for idx,t in enumerate(pattern['buggy']):
        if 'Idf_' in t:
            b.append(pattern['buggy_actual'][idx])
    for op in toks:
        if op in f and op in b:
            f_idx = pattern['fix_actual'].index(op)
            b_idx = pattern['buggy_actual'].index(op)
            f_regex = pattern['fix_actual'][f_idx+2:f_idx+3]
            b_regex = pattern['buggy_actual'][f_idx+2:f_idx+3]
            # print(b_regex)
            # print(f_regex)
            cr = (b_regex[0][-1]=='g' and f_regex[0][-1]!='g') or (b_regex[0][-1]!='g' and f_regex[0][-1]=='g')
            if cr and pattern['url'] not in seen_url:
                seen_url.add(pattern['url'])
                selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 7
#                                           fix_actual  \
# 0  [return, (, t, ||, "", ), ., replace, (, /^\s+...
# 1  [return, markup, ., replace, (, /&/g, ,, "&amp...
# 2  [cwd, =, process, ., cwd, (, ), ., replace, (,...
# 3  [textMessage, =, textMessage, ., replace, (, /...
# 4  [textMessage, =, textMessage, ., replace, (, /...
# 5  [suffix, =, suffix, &&, suffix, ., replace, (,...
# 6  [const, jsCode, =, transformResult, ., code, ....
#
#                                         buggy_actual
# 0  [return, t, ., replace, (, /^\s+|\s+$/g, ,, ""...
# 1  [return, markup, ., replace, (, "&", ,, "&amp;...
# 2  [cwd, =, process, ., cwd, (, ), ., replace, (,...
# 3  [textMessage, =, textMessage, ., replace, (, '...
# 4  [textMessage, =, textMessage, ., replace, (, '...
# 5  [suffix, =, suffix, &&, suffix, ., replace, (,...
# 6  [const, jsCode, =, unescape, (, transformResul...

# %% [markdown]
# Selected the following

# %%
print(selected_patterns.iloc[1,4])
print(selected_patterns.iloc[5,4])
# Out:
# https://github.com/select2/select2/commit/b422d4efef486e8ac724220229e0c6d42b7f28ad
# https://github.com/emberjs/ember.js/commit/2e99d1ff3b8a28f966b52c12cb5109b377216c10

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[5,4]].sort_values(by='mean_similarity')
p
# Out:
#                                  file_name_where_intended  \
# 611641  benchmarks/data/thomaschampagne/StravaPlus/hoo...
# 257971  benchmarks/data/malikov/Authenticate.me-Node-S...
# 322005  benchmarks/data/derdesign/protos/lib/controlle...
# 122967  benchmarks/data/sgruhier/typeahead-addresspick...
# 47946   benchmarks/data/route360/r360-js/src/control/P...
# 339299  benchmarks/data/sstrigler/JSJaC/utils/jsdoc3/t...
#
#                             target_token_sequence-Correct  \
# 611641  [return, brng, ., replace, (, "360", ,, "0", )...
# 257971  [return, description, ., replace, (, /\d+/g, ,...
# 322005    [return, val, ., replace, (, /^_/, ,, "", ), ;]
# 122967  [return, str, ., replace, (, /[\-\[\]\/\{\}\(\...
# 47946   [return, queryToEscape, ., replace, (, /([.?*+...
# 339299  [return, str, ., replace, (, /</g, ,, "&lt;", ...
#
#                               target_token_sequence-Buggy  \
# 611641   [return, brng, ., replace, (, "=", ,, "0", ), ;]
# 257971  [return, description, ., replace, (, "=", ,, "...
# 322005     [return, val, ., replace, (, "=", ,, "", ), ;]
# 122967  [return, str, ., replace, (, "=", ,, "\\$&", )...
# 47946   [return, queryToEscape, ., replace, (, "=", ,,...
# 339299  [return, str, ., replace, (, "=", ,, "&lt;", )...
#
#                        token_sequence_abstraction-Correct  \
# 611641  [return, Idf_1, ., Idf_2, (, Lit_1, ,, Lit_2, ...
# 257971  [return, Idf_1, ., Idf_2, (, Lit_1, ,, Lit_2, ...
# 322005  [return, Idf_1, ., Idf_2, (, Lit_1, ,, Lit_2, ...
# 122967  [return, Idf_1, ., Idf_2, (, Lit_1, ,, Lit_2, ...
# 47946   [return, Idf_1, ., Idf_2, (, Lit_1, ,, Lit_2, ...
# 339299  [return, Idf_1, ., Idf_2, (, Lit_1, ,, Lit_2, ...
#
#                          token_sequence_abstraction-Buggy  \
# 611641  [return, Idf_1, ., Idf_2, (, Lit_3, ,, Lit_2, ...
# 257971  [return, Idf_1, ., Idf_2, (, Lit_3, ,, Lit_2, ...
# 322005  [return, Idf_1, ., Idf_2, (, Lit_3, ,, Lit_2, ...
# 122967  [return, Idf_1, ., Idf_2, (, Lit_3, ,, Lit_2, ...
# 47946   [return, Idf_1, ., Idf_2, (, Lit_3, ,, Lit_2, ...
# 339299  [return, Idf_1, ., Idf_2, (, Lit_3, ,, Lit_2, ...
#
#                                    target_line_range  \
# 611641      {'line': '86-86', 'range': [2795, 2827]}
# 257971  {'line': '227-227', 'range': [11638, 11677]}
# 322005        {'line': '30-30', 'range': [881, 910]}
# 122967        {'line': '12-12', 'range': [432, 498]}
# 47946   {'line': '158-158', 'range': [12463, 12526]}
# 339299        {'line': '22-22', 'range': [700, 733]}
#
#         num_of_available_identifiers_to_choose_from  \
# 611641                                         1017
# 257971                                         1122
# 322005                                         1087
# 122967                                         1298
# 47946                                          1074
# 339299                                         1086
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 611641                                      1020  False          0.42450
# 257971                                      1022  False          0.52350
# 322005                                      1034  False          0.54775
# 122967                                      1137  False          0.66400
# 47946                                       1096  False          0.67950
# 339299                                      1073  False          0.78075
#
#                                       seeding_pattern_url
# 611641  https://github.com/select2/select2/commit/b422...
# 257971  https://github.com/select2/select2/commit/b422...
# 322005  https://github.com/select2/select2/commit/b422...
# 122967  https://github.com/select2/select2/commit/b422...
# 47946   https://github.com/select2/select2/commit/b422...
# 339299  https://github.com/select2/select2/commit/b422...

# %%
p.iloc[1,0]
# Out:
# 'benchmarks/data/malikov/Authenticate.me-Node-Server/node_modules/node-inspector/front-end/CanvasReplayStateView.js'

# %% [markdown]
# #### 3. Removing the integer base argument from parseInt
# **Note:** Although many patterns exist that contain *parseInt* there does not exist
# anything that captures exactly what mutandis does

# %%
selected_patterns = []
toks = ['parseInt']
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    for idx,t in enumerate(pattern['fix']):
        if 'Idf_' in t:
            f.append(pattern['fix_actual'][idx])
    for idx,t in enumerate(pattern['buggy']):
        if 'Idf_' in t:
            b.append(pattern['buggy_actual'][idx])
    for op in toks:
        if op in f and op in b:
            selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 4
#                                           fix_actual  \
# 0  [safari2, =, safari, &&, parseInt, (, version,...
# 1  [parseInt, (, process, ., versions, ., openssl...
# 2  [padding, =, parseInt, (, getComputedStyle, (,...
# 3  [timeout, =, parseInt, (, args, [, 1, ], ||, 2...
#
#                                         buggy_actual
# 0  [safari2, =, safari, &&, parseInt, (, version,...
# 1  [parseInt, (, process, ., versions, ., openssl...
# 2  [padding, =, parseInt, (, getComputedStyle, (,...
# 3  [timeout, =, parseInt, (, args, [, 1, ], ||, 1...

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[1,4]].sort_values(by='mean_similarity')
p

# %% [markdown]
# #### 4. Changing setTimeout function
# **Note:** The exact pattern as expected by mutandis does not exist

# %%
selected_patterns = []
toks = ['setTimeout','setInterval']
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    for idx,t in enumerate(pattern['fix']):
        if 'Idf_' in t:
            f.append(pattern['fix_actual'][idx])
    for idx,t in enumerate(pattern['buggy']):
        if 'Idf_' in t:
            b.append(pattern['buggy_actual'][idx])
    for op in toks:
        if op in f and op in b:
            selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 5
#                                           fix_actual  \
# 0  [i, ==, null, ||, typeof, array, ==, 'string',...
# 1  [elem, ., setInterval, &&, (, elem, !=, window...
# 2              [setTimeout, (, start, ,, 1000, ), ;]
# 3             [socket, ., setTimeout, (, 9999, ), ;]
# 4  [setTimeout, (, (, ), =>, {, this, ., resume, ...
#
#                                         buggy_actual
# 0  [i, ==, null, ||, typeof, array, ==, 'function...
# 1       [elem, ., setInterval, &&, elem, !=, window]
# 2               [setTimeout, (, start, ,, 100, ), ;]
# 3             [socket, ., setTimeout, (, 1000, ), ;]
# 4  [setTimeout, (, (, ), =>, {, this, ., resume, ...

# %% [markdown]
# #### 5. Replacing 'undefined' with 'null'
# **None found**

# %%
selected_patterns = []
toks = ['undefined']
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    f = []
    b = []
    if len(pattern['fix']) != len(pattern['buggy']):
        continue
    for idx,t in enumerate(pattern['fix']):
        if 'Idf_' in t:
            f.append(pattern['fix_actual'][idx])
    for idx,t in enumerate(pattern['buggy']):
        if 'Idf_' in t:
            b.append(pattern['buggy_actual'][idx])
    for op in toks:
        if op in f  and 'null' in pattern['buggy_actual']:
            list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
            selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 1
#                                           fix_actual  \
# 0  [s, ., dataType, ===, "script", &&, s, ., cach...
#
#                                         buggy_actual
# 0  [s, ., dataType, ===, "script", &&, s, ., cach...

# %%
print(selected_patterns.iloc[0,8])
print(selected_patterns.iloc[0,14])
# Out:
# ['s', '.', 'dataType', '===', '"script"', '&&', 's', '.', 'cache', '===', 'undefined']
# ['s', '.', 'dataType', '===', '"script"', '&&', 's', '.', 'cache', '===', 'null']

# %% [markdown]
# Selected the following

# %% [markdown]
# Selected the following

# %%
print(selected_patterns.iloc[5,4])
# Out:
# https://github.com/lerna/lerna/commit/2fa02a835c2c898dce5e8aa1d27d3eed3854c529

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]].sort_values(by='mean_similarity')
p
# Out:
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url, commit_hash]
# Index: []

# %% [markdown]
# #### 6. Removing 'this' keyword

# %%
selected_patterns = []
tok = 'this'
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    if tok in pattern['fix_actual'] and tok not in pattern['buggy_actual'] and len(pattern['buggy_actual'])+1==len(pattern['fix_actual']):
        selected_patterns.append(pattern)
        list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 2
#                                           fix_actual  \
# 0  [exports, ., EventEmitter, ., call, (, this, )...
# 1      [if, (, !, handler, ), {, return, this, ;, }]
#
#                                    buggy_actual
# 0  [exports, ., EventEmitter, ., call, (, ), ;]
# 1       [if, (, !, handler, ), {, return, ;, }]

# %% [markdown]
# Selected the following

# %%
selected_patterns.iloc[0]
# Out:
# _id                nodejs/node_87d92f619a9b6c307a45e5a92ae63152e3...
# commit_hash                 87d92f619a9b6c307a45e5a92ae63152e3b5b059
# commit_time                                     20/01/2010, 23:59:38
# local_repo_path                         ../results/top_JS_repos/node
# url                https://github.com/nodejs/node/commit/87d92f61...
# fix                       [Idf_1, ., Idf_2, ., Idf_3, (, this, ), ;]
# fix_tokenType                                    ExpressionStatement
# fix_file_path                                            src/node.js
# fix_actual         [exports, ., EventEmitter, ., call, (, this, )...
# fix_range                                               [6352, 6384]
# fix_line                                                     195-195
# buggy                           [Idf_1, ., Idf_2, ., Idf_3, (, ), ;]
# buggy_tokenType                                  ExpressionStatement
# buggy_file_path                                          src/node.js
# buggy_actual            [exports, ., EventEmitter, ., call, (, ), ;]
# buggy_range                                             [6352, 6380]
# buggy_line                                                   195-195
# Name: 0, dtype: object

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]].sample(5).sort_values(by='mean_similarity')
p
# Out:
#                                  file_name_where_intended  \
# 426945  benchmarks/data/malikov/Authenticate.me-Node-S...
# 333620  benchmarks/data/auchenberg/chrome-devtools-app...
# 588789  benchmarks/data/ondras/rot.js/src/scheduler/sc...
# 26301   benchmarks/data/substance/visual-editor/lib/oo...
# 313059           benchmarks/data/deoxxa/jsmc/lib/chunk.js
#
#                             target_token_sequence-Correct  \
# 426945    [WebInspector, ., View, ., call, (, this, ), ;]
# 333620    [WebInspector, ., VBox, ., call, (, this, ), ;]
# 588789        [ROT, ., Scheduler, ., call, (, this, ), ;]
# 26301       [oo, ., EventEmitter, ., call, (, this, ), ;]
# 313059  [events, ., EventEmitter, ., call, (, this, ), ;]
#
#                         target_token_sequence-Buggy  \
# 426945    [WebInspector, ., View, ., call, (, ), ;]
# 333620    [WebInspector, ., VBox, ., call, (, ), ;]
# 588789        [ROT, ., Scheduler, ., call, (, ), ;]
# 26301       [oo, ., EventEmitter, ., call, (, ), ;]
# 313059  [events, ., EventEmitter, ., call, (, ), ;]
#
#                 token_sequence_abstraction-Correct  \
# 426945  [Idf_1, ., Idf_2, ., Idf_3, (, this, ), ;]
# 333620  [Idf_1, ., Idf_2, ., Idf_3, (, this, ), ;]
# 588789  [Idf_1, ., Idf_2, ., Idf_3, (, this, ), ;]
# 26301   [Idf_1, ., Idf_2, ., Idf_3, (, this, ), ;]
# 313059  [Idf_1, ., Idf_2, ., Idf_3, (, this, ), ;]
#
#             token_sequence_abstraction-Buggy  \
# 426945  [Idf_1, ., Idf_2, ., Idf_3, (, ), ;]
# 333620  [Idf_1, ., Idf_2, ., Idf_3, (, ), ;]
# 588789  [Idf_1, ., Idf_2, ., Idf_3, (, ), ;]
# 26301   [Idf_1, ., Idf_2, ., Idf_3, (, ), ;]
# 313059  [Idf_1, ., Idf_2, ., Idf_3, (, ), ;]
#
#                                    target_line_range  \
# 426945            {'line': '2-2', 'range': [68, 97]}
# 333620            {'line': '2-2', 'range': [48, 77]}
# 588789            {'line': '2-2', 'range': [40, 65]}
# 26301   {'line': '300-300', 'range': [10612, 10639]}
# 313059          {'line': '4-4', 'range': [116, 147]}
#
#         num_of_available_identifiers_to_choose_from  \
# 426945                                         1122
# 333620                                         1059
# 588789                                         1009
# 26301                                          1050
# 313059                                         1017
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 426945                                      1022  False         0.527667
# 333620                                      1009  False         0.541333
# 588789                                      1000  False         0.562667
# 26301                                       1014  False         0.752000
# 313059                                      1014  False         0.769667
#
#                                       seeding_pattern_url
# 426945  https://github.com/nodejs/node/commit/87d92f61...
# 333620  https://github.com/nodejs/node/commit/87d92f61...
# 588789  https://github.com/nodejs/node/commit/87d92f61...
# 26301   https://github.com/nodejs/node/commit/87d92f61...
# 313059  https://github.com/nodejs/node/commit/87d92f61...

# %% [markdown]
# #### 7. Replacing (function()!==false) by (function())
# **Note:** Could not find any instance

# %%
selected_patterns = []
tok = ')!==false'
rep_tok = ')'
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    if tok in ''.join(pattern['fix_actual']) and rep_tok in ''.join(pattern['buggy_actual']):
        selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 1
#                                        fix_actual  \
# 0  [config, ., get, (, 'compress', ), !==, false]
#
#                                         buggy_actual
# 0  [config, ., get, (, 'server', ), ., compress, ...

# %% [markdown]
# ## Variable mutation
# The following are few mutation operators that do not overlap with the branch mutation
# operators
#
# #### Change the value assigned to the variable

# %%
selected_patterns = []
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    if ['var', 'Idf_1', '=']==pattern['fix'][0:3] == pattern['buggy'][0:3]:
        if pattern['fix'][3] !=  pattern['buggy'][3]:
            selected_patterns.append(pattern)
            list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 88
#                                            fix_actual  \
# 0   [var, blockMatch, =, /\s*\/\*\*\s*((.|\n|\r\n)...
# 1   [var, exclude, =, /z-?index|font-?weight|opaci...
# 2   [var, exclude, =, /z-?index|font-?weight|opaci...
# 3   [var, cmd, =, 'NODE_PATH=', +, libDir, +, ' ',...
# 4    [var, initial, =, arguments, ., length, >, 2, ;]
# ..                                                ...
# 83                  [var, $this, =, $, (, this, ), ;]
# 84         [var, noDead, =, new, URL, (, input, ), ;]
# 85  [var, validFontSizeRegExpStr, =, "^([0-9]+)?(\...
# 86  [var, stats, =, compilation, ?, this, ., _getS...
# 87  [var, diff, =, wrap, (, center, ), -, clickedI...
#
#                                          buggy_actual
# 0   [var, blockMatch, =, /\s*\/\*\*\s*((.|\n)*?)\s...
# 1   [var, exclude, =, /z-?index|font-?weight|opaci...
# 2   [var, exclude, =, /z-?index|font-?weight|opaci...
# 3   [var, cmd, =, nodeBinary, +, ' http://localhos...
# 4            [var, initial, =, memo, !==, void, 0, ;]
# ..                                                ...
# 83             [var, $this, =, jQuery, (, this, ), ;]
# 84    [var, noDead, =, url, ., parse, (, input, ), ;]
# 85  [var, validFontSizeRegExpStr, =, "^([0-9]+)?(....
# 86  [var, stats, =, this, ., _getStats, (, compila...
# 87  [var, diff, =, (, center, %, count, ), -, clic...
#
# [88 rows x 2 columns]

# %%
selected_patterns.sample(3)
# Out:
#                                                   _id  \
# 3   nodejs/node_a021db151a6c890281e4367d2a2319290c...
# 57  jashkenas/underscore_68d8b763fa75c3912217e7b08...
# 29  meteor/meteor_e15ab4fc21a3c46ceab9f102897999cb...
#
#                                  commit_hash           commit_time  \
# 3   a021db151a6c890281e4367d2a2319290c70576d  07/11/2009, 20:07:55
# 57  68d8b763fa75c3912217e7b08d36637a6140b1a1  26/01/2015, 18:53:53
# 29  e15ab4fc21a3c46ceab9f102897999cb7ed3ada5  31/07/2013, 02:10:03
#
#                        local_repo_path  \
# 3         ../results/top_JS_repos/node
# 57  ../results/top_JS_repos/underscore
# 29      ../results/top_JS_repos/meteor
#
#                                                   url  \
# 3   https://github.com/nodejs/node/commit/a021db15...
# 57  https://github.com/jashkenas/underscore/commit...
# 29  https://github.com/meteor/meteor/commit/e15ab4...
#
#                                                   fix        fix_tokenType  \
# 3   [var, Idf_1, =, Lit_1, +, Idf_2, +, Lit_2, +, ...  VariableDeclaration
# 57                             [var, Idf_1, =, Lit_1]  VariableDeclaration
# 29                          [var, Idf_1, =, Lit_1, ;]  VariableDeclaration
#
#                                  fix_file_path  \
# 3   test/mjsunit/test-remote-module-loading.js
# 57                               underscore.js
# 29                        packages/ui/attrs.js
#
#                                            fix_actual     fix_range fix_line  \
# 3   [var, cmd, =, 'NODE_PATH=', +, libDir, +, ' ',...    [603, 688]    24-24
# 57                                 [var, index, =, 1]  [3543, 3556]  102-102
# 29  [var, ATTRIBUTE_NAME_REGEX, =, /^[^\s"'>/=]+$/...       [1, 44]      2-2
#
#                                                 buggy      buggy_tokenType  \
# 3   [var, Idf_1, =, Idf_3, +, Lit_3, +, Idf_4, +, ...  VariableDeclaration
# 57                             [var, Idf_1, =, Lit_2]  VariableDeclaration
# 29                          [var, Idf_1, =, Lit_2, ;]  VariableDeclaration
#
#                                buggy_file_path  \
# 3   test/mjsunit/test-remote-module-loading.js
# 57                               underscore.js
# 29                        packages/ui/attrs.js
#
#                                          buggy_actual   buggy_range buggy_line
# 3   [var, cmd, =, nodeBinary, +, ' http://localhos...    [603, 664]      24-24
# 57                                 [var, index, =, 0]  [3543, 3556]    102-102
# 29  [var, ATTRIBUTE_NAME_REGEX, =, /^[^\s"'>/=/]+$...       [1, 45]        2-2

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[57,4]].sort_values(by='mean_similarity')
p
# Out:
#                                  file_name_where_intended  \
# 304175  benchmarks/data/jxcore/jxcore/deps/mozjs/src/t...
# 261621  benchmarks/data/paullewis/a3/deploy/www/sample...
# 507088  benchmarks/data/icodeforlove/node-requester/li...
# 93758   benchmarks/data/icodeforlove/node-requester/li...
# 196663  benchmarks/data/paullewis/a3/deploy/www/sample...
# ...                                                   ...
# 213353  benchmarks/data/stackforge/compass-web/v1/ods/...
# 353220  benchmarks/data/sebastienros/jint/Jint.Tests.E...
# 323819  benchmarks/data/sharelatex/web-sharelatex/publ...
# 13633   benchmarks/data/oreillymedia/data_structures_a...
# 37139   benchmarks/data/malikov/Authenticate.me-Node-S...
#
#        target_token_sequence-Correct target_token_sequence-Buggy  \
# 304175                [var, m, =, 0]              [var, m, =, 1]
# 261621                [var, w, =, 0]            [var, w, =, 120]
# 507088            [var, proxy, =, 0]         [var, proxy, =, 80]
# 93758             [var, proxy, =, 0]         [var, proxy, =, 80]
# 196663                [var, v, =, 0]            [var, v, =, 100]
# ...                              ...                         ...
# 213353                [var, i, =, 1]              [var, i, =, 0]
# 353220                [var, i, =, 1]              [var, i, =, 0]
# 323819                [var, i, =, 1]              [var, i, =, 0]
# 13633                 [var, i, =, 1]              [var, i, =, 0]
# 37139             [var, index, =, 0]          [var, index, =, 1]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 304175             [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 261621             [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 507088             [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 93758              [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 196663             [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# ...                                   ...                              ...
# 213353             [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 353220             [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 323819             [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 13633              [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
# 37139              [var, Idf_1, =, Lit_1]           [var, Idf_1, =, Lit_2]
#
#                                    target_line_range  \
# 304175        {'line': '15-15', 'range': [284, 293]}
# 261621    {'line': '138-138', 'range': [4629, 4638]}
# 507088      {'line': '62-62', 'range': [2839, 2852]}
# 93758       {'line': '73-73', 'range': [3228, 3241]}
# 196663      {'line': '76-76', 'range': [2153, 2162]}
# ...                                              ...
# 213353  {'line': '219-219', 'range': [12402, 12411]}
# 353220            {'line': '3-3', 'range': [48, 57]}
# 323819        {'line': '12-12', 'range': [529, 538]}
# 13633             {'line': '3-3', 'range': [55, 64]}
# 37139       {'line': '42-42', 'range': [2621, 2634]}
#
#         num_of_available_identifiers_to_choose_from  \
# 304175                                         1007
# 261621                                         1108
# 507088                                         1048
# 93758                                          1048
# 196663                                         1108
# ...                                             ...
# 213353                                         1104
# 353220                                         1003
# 323819                                         1050
# 13633                                          1002
# 37139                                          1122
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 304175                                      1003  False           0.5455
# 261621                                      1037  False           0.5600
# 507088                                      1017  False           0.5660
# 93758                                       1017  False           0.5660
# 196663                                      1037  False           0.5760
# ...                                          ...    ...              ...
# 213353                                      1090  False           0.8265
# 353220                                      1000  False           0.8265
# 323819                                      1020  False           0.8265
# 13633                                       1000  False           0.8265
# 37139                                       1022  False           0.9270
#
#                                       seeding_pattern_url
# 304175  https://github.com/jashkenas/underscore/commit...
# 261621  https://github.com/jashkenas/underscore/commit...
# 507088  https://github.com/jashkenas/underscore/commit...
# 93758   https://github.com/jashkenas/underscore/commit...
# 196663  https://github.com/jashkenas/underscore/commit...
# ...                                                   ...
# 213353  https://github.com/jashkenas/underscore/commit...
# 353220  https://github.com/jashkenas/underscore/commit...
# 323819  https://github.com/jashkenas/underscore/commit...
# 13633   https://github.com/jashkenas/underscore/commit...
# 37139   https://github.com/jashkenas/underscore/commit...
#
# [185 rows x 11 columns]

# %% [markdown]
# #### Remove variable declaration

# %%
selected_patterns = []
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    if ['var', 'Idf_1', '=']==pattern['fix'][0:3] and pattern['buggy'][0:2] == ['Idf_1', '=']:
            list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
            selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 15
#                                            fix_actual  \
# 0             [var, i, =, 0, ,, l, =, not, ., length]
# 1   [var, filter, =, style, ., filter, ||, jQuery,...
# 2   [var, match, =, jQuery, ., noData, [, elem, .,...
# 3           [var, encoding, =, arguments, [, 3, ], ;]
# 4   [var, stats, =, fs, ., statSync, (, requestPat...
# 5   [var, envDialect, =, process, ., env, ., DIALE...
# 6   [var, appView, =, Discourse, ., __container__,...
# 7    [var, promise, =, new, Em, ., Deferred, (, ), ;]
# 8                [var, opts, =, options, ||, {, }, ;]
# 9        [var, o, =, 0, ,, ol, =, offsets, ., length]
# 10      [var, v, =, 1, ,, vl, =, vertices, ., length]
# 11                          [var, result, =, true, ;]
# 12           [var, run, =, s, ., run, (, "run", ), ;]
# 13  [var, triangleNode, =, triangleNodes, [, i, ], ;]
# 14              [var, lStack, =, (, ++, _stack, ), ;]
#
#                                          buggy_actual
# 0                  [i, =, 0, ,, l, =, not, ., length]
# 1   [filter, =, style, ., filter, ||, jQuery, ., c...
# 2   [match, =, jQuery, ., noData, [, elem, ., node...
# 3                [encoding, =, arguments, [, 3, ], ;]
# 4   [stats, =, fs, ., statSync, (, requestPath, ), ;]
# 5   [envDialect, =, process, ., env, ., DIALECT, |...
# 6   [appView, =, Discourse, ., __container__, ., l...
# 7         [promise, =, new, Em, ., Deferred, (, ), ;]
# 8                     [opts, =, options, ||, {, }, ;]
# 9             [o, =, 0, ,, ol, =, offsets, ., length]
# 10           [v, =, 1, ,, vl, =, vertices, ., length]
# 11                               [result, =, true, ;]
# 12                [run, =, s, ., run, (, "run", ), ;]
# 13       [triangleNode, =, triangleNodes, [, i, ], ;]
# 14                   [lStack, =, (, ++, _stack, ), ;]

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]].sort_values(by='mean_similarity')
p
# Out:
#                                  file_name_where_intended  \
# 23718   benchmarks/data/ariatemplates/ariatemplates/te...
# 102132  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 388527  benchmarks/data/NV/chrome-devtools-autosave/ch...
# 372610  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 241712  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 392550  benchmarks/data/digitalbiblesociety/browserbib...
# 526949  benchmarks/data/digitalbiblesociety/browserbib...
# 73572   benchmarks/data/digitalbiblesociety/browserbib...
# 524839  benchmarks/data/NV/chrome-devtools-autosave/ch...
# 61565   benchmarks/data/digitalbiblesociety/browserbib...
# 180692  benchmarks/data/kazuyukitanimura/designo/twitt...
# 589370  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 125670  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 156384  benchmarks/data/LearnBoost/cluster/lib/mixins/...
# 651555  benchmarks/data/ariatemplates/ariatemplates/te...
# 26520   benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 186630  benchmarks/data/ariatemplates/ariatemplates/te...
# 302787  benchmarks/data/yuguang/fiddlesalad/static/js/...
# 461033  benchmarks/data/malikov/Authenticate.me-Node-S...
# 566746  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 436076  benchmarks/data/cdnjs/cdnjs/ajax/libs/topojson...
# 525762  benchmarks/data/malikov/Authenticate.me-Node-S...
# 206818  benchmarks/data/malikov/Authenticate.me-Node-S...
# 549008  benchmarks/data/sgruhier/typeahead-addresspick...
# 400251  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 153687  benchmarks/data/malikov/Authenticate.me-Node-S...
# 190278  benchmarks/data/sgruhier/typeahead-addresspick...
# 636113  benchmarks/data/malikov/Authenticate.me-Node-S...
# 124885  benchmarks/data/ozoneplatform/owf-framework/we...
# 107566  benchmarks/data/owenXin/microblogByOwen/node_m...
# 73425   benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 530600  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 218002  benchmarks/data/cdnjs/cdnjs/ajax/libs/react-ro...
# 443725  benchmarks/data/yuguang/fiddlesalad/static/js/...
# 522487  benchmarks/data/snakajima/AJMax.js/node_module...
# 568672  benchmarks/data/basho/riagi/riagi/static/ender.js
# 626145  benchmarks/data/ariatemplates/ariatemplates/te...
# 59647   benchmarks/data/ariatemplates/ariatemplates/te...
# 93370   benchmarks/data/ariatemplates/ariatemplates/sr...
# 208815  benchmarks/data/cdnjs/cdnjs/ajax/libs/yui/3.0....
# 543143  benchmarks/data/asm-products/notello/node_modu...
# 50868         benchmarks/data/kriszyp/xstyle/core/Rule.js
# 553389  benchmarks/data/basho/riagi/riagi/static/ender.js
#
#                             target_token_sequence-Correct  \
# 23718     [var, j, =, 0, ,, tcl, =, testCases, ., length]
# 102132          [var, k, =, 0, ,, kl, =, keys, ., length]
# 388527         [var, i, =, 0, ,, ii, =, rules, ., length]
# 372610       [var, i, =, 0, ,, il, =, objKeys, ., length]
# 241712       [var, i, =, 0, ,, il, =, objKeys, ., length]
# 392550  [var, i, =, 0, ,, il, =, verseLocations, ., le...
# 526949  [var, i, =, 0, ,, il, =, locationData, ., length]
# 73572   [var, i, =, 0, ,, il, =, locationData, ., length]
# 524839  [var, i, =, 0, ,, ii, =, serversElements, ., l...
# 61565   [var, i, =, 0, ,, il, =, contentToHighlight, ....
# 180692       [var, i, =, 0, ,, len, =, chunks, ., length]
# 589370         [var, i, =, 0, ,, il, =, parts, ., length]
# 125670        [var, i, =, 0, ,, il, =, source, ., length]
# 156384        [var, i, =, 0, ,, len, =, chunk, ., length]
# 651555    [var, j, =, 0, ,, len, =, testCases, ., length]
# 26520           [var, i, =, 0, ,, il, =, keys, ., length]
# 186630    [var, index1, =, 0, ,, l, =, months, ., length]
# 302787     [var, i, =, 0, ,, j, =, editScript, ., length]
# 461033  [var, i, =, 0, ,, n, =, collectedResources, .,...
# 566746           [var, i, =, 0, ,, il, =, obj, ., length]
# 436076           [var, i, =, 0, ,, n, =, arcs, ., length]
# 525762    [var, i, =, 0, ,, n, =, descriptors, ., length]
# 206818    [var, i, =, 0, ,, n, =, descriptors, ., length]
# 549008    [var, i, =, 0, ,, len, =, callbacks, ., length]
# 400251   [var, i, =, 0, ,, len, =, paramNames, ., length]
# 153687       [var, i, =, 0, ,, n, =, contexts, ., length]
# 190278     [var, i, =, 0, ,, len, =, patterns, ., length]
# 636113          [var, i, =, 0, ,, n, =, calls, ., length]
# 124885        [var, i, =, 0, ,, len, =, elems, ., length]
# 107566         [var, i, =, 0, ,, len, =, keys, ., length]
# 73425   [var, i, =, 0, ,, len, =, childRoutes, ., length]
# 530600       [var, i, =, 0, ,, len, =, routes, ., length]
# 218002       [var, i, =, 0, ,, len, =, routes, ., length]
# 443725          [var, i, =, 0, ,, j, =, array, ., length]
# 522487           [var, i, =, 0, ,, l, =, bufs, ., length]
# 568672             [var, i, =, 0, ,, j, =, ar, ., length]
# 626145       [var, i, =, 0, ,, l, =, patterns, ., length]
# 59647        [var, i, =, 0, ,, l, =, patterns, ., length]
# 93370         [var, i, =, 0, ,, l, =, scripts, ., length]
# 208815  [var, i, =, 0, ,, l, =, localeSegments, ., len...
# 543143           [var, i, =, 0, ,, l, =, data, ., length]
# 50868   [var, i, =, 0, ,, l, =, existingValues, ., len...
# 553389             [var, i, =, 0, ,, l, =, ar, ., length]
#
#                               target_token_sequence-Buggy  \
# 23718          [j, =, 0, ,, tcl, =, testCases, ., length]
# 102132               [k, =, 0, ,, kl, =, keys, ., length]
# 388527              [i, =, 0, ,, ii, =, rules, ., length]
# 372610            [i, =, 0, ,, il, =, objKeys, ., length]
# 241712            [i, =, 0, ,, il, =, objKeys, ., length]
# 392550     [i, =, 0, ,, il, =, verseLocations, ., length]
# 526949       [i, =, 0, ,, il, =, locationData, ., length]
# 73572        [i, =, 0, ,, il, =, locationData, ., length]
# 524839    [i, =, 0, ,, ii, =, serversElements, ., length]
# 61565   [i, =, 0, ,, il, =, contentToHighlight, ., len...
# 180692            [i, =, 0, ,, len, =, chunks, ., length]
# 589370              [i, =, 0, ,, il, =, parts, ., length]
# 125670             [i, =, 0, ,, il, =, source, ., length]
# 156384             [i, =, 0, ,, len, =, chunk, ., length]
# 651555         [j, =, 0, ,, len, =, testCases, ., length]
# 26520                [i, =, 0, ,, il, =, keys, ., length]
# 186630         [index1, =, 0, ,, l, =, months, ., length]
# 302787          [i, =, 0, ,, j, =, editScript, ., length]
# 461033  [i, =, 0, ,, n, =, collectedResources, ., length]
# 566746                [i, =, 0, ,, il, =, obj, ., length]
# 436076                [i, =, 0, ,, n, =, arcs, ., length]
# 525762         [i, =, 0, ,, n, =, descriptors, ., length]
# 206818         [i, =, 0, ,, n, =, descriptors, ., length]
# 549008         [i, =, 0, ,, len, =, callbacks, ., length]
# 400251        [i, =, 0, ,, len, =, paramNames, ., length]
# 153687            [i, =, 0, ,, n, =, contexts, ., length]
# 190278          [i, =, 0, ,, len, =, patterns, ., length]
# 636113               [i, =, 0, ,, n, =, calls, ., length]
# 124885             [i, =, 0, ,, len, =, elems, ., length]
# 107566              [i, =, 0, ,, len, =, keys, ., length]
# 73425        [i, =, 0, ,, len, =, childRoutes, ., length]
# 530600            [i, =, 0, ,, len, =, routes, ., length]
# 218002            [i, =, 0, ,, len, =, routes, ., length]
# 443725               [i, =, 0, ,, j, =, array, ., length]
# 522487                [i, =, 0, ,, l, =, bufs, ., length]
# 568672                  [i, =, 0, ,, j, =, ar, ., length]
# 626145            [i, =, 0, ,, l, =, patterns, ., length]
# 59647             [i, =, 0, ,, l, =, patterns, ., length]
# 93370              [i, =, 0, ,, l, =, scripts, ., length]
# 208815      [i, =, 0, ,, l, =, localeSegments, ., length]
# 543143                [i, =, 0, ,, l, =, data, ., length]
# 50868       [i, =, 0, ,, l, =, existingValues, ., length]
# 553389                  [i, =, 0, ,, l, =, ar, ., length]
#
#                        token_sequence_abstraction-Correct  \
# 23718   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 102132  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 388527  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 372610  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 241712  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 392550  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 526949  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 73572   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 524839  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 61565   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 180692  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 589370  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 125670  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 156384  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 651555  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 26520   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 186630  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 302787  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 461033  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 566746  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 436076  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 525762  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 206818  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 549008  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 400251  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 153687  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 190278  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 636113  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 124885  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 107566  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 73425   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 530600  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 218002  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 443725  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 522487  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 568672  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 626145  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 59647   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 93370   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 208815  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 543143  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 50868   [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
# 553389  [var, Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., ...
#
#                        token_sequence_abstraction-Buggy  \
# 23718   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 102132  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 388527  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 372610  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 241712  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 392550  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 526949  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 73572   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 524839  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 61565   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 180692  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 589370  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 125670  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 156384  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 651555  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 26520   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 186630  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 302787  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 461033  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 566746  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 436076  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 525762  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 206818  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 549008  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 400251  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 153687  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 190278  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 636113  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 124885  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 107566  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 73425   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 530600  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 218002  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 443725  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 522487  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 568672  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 626145  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 59647   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 93370   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 208815  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 543143  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 50868   [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
# 553389  [Idf_1, =, Lit_1, ,, Idf_2, =, Idf_3, ., Idf_4]
#
#                                      target_line_range  \
# 23718         {'line': '70-70', 'range': [4319, 4352]}
# 102132  {'line': '1850-1850', 'range': [81716, 81743]}
# 388527        {'line': '59-59', 'range': [1737, 1765]}
# 372610  {'line': '1993-1993', 'range': [87185, 87215]}
# 241712  {'line': '1966-1966', 'range': [85893, 85923]}
# 392550      {'line': '203-203', 'range': [7992, 8029]}
# 526949      {'line': '121-121', 'range': [4720, 4755]}
# 73572         {'line': '70-70', 'range': [2966, 3001]}
# 524839      {'line': '298-298', 'range': [9237, 9275]}
# 61565       {'line': '190-190', 'range': [7472, 7513]}
# 180692      {'line': '238-238', 'range': [7738, 7768]}
# 589370  {'line': '2011-2011', 'range': [87927, 87955]}
# 125670  {'line': '1823-1823', 'range': [80782, 80811]}
# 156384             {'line': '4-4', 'range': [99, 128]}
# 651555        {'line': '89-89', 'range': [5358, 5391]}
# 26520   {'line': '2091-2091', 'range': [91550, 91577]}
# 186630        {'line': '48-48', 'range': [3112, 3145]}
# 302787    {'line': '286-286', 'range': [13348, 13380]}
# 461033      {'line': '133-133', 'range': [7051, 7091]}
# 566746  {'line': '1880-1880', 'range': [82714, 82740]}
# 436076      {'line': '197-197', 'range': [7481, 7507]}
# 525762      {'line': '108-108', 'range': [5906, 5939]}
# 206818      {'line': '196-196', 'range': [9858, 9891]}
# 549008      {'line': '286-286', 'range': [9349, 9382]}
# 400251  {'line': '1026-1026', 'range': [44222, 44256]}
# 153687        {'line': '98-98', 'range': [5304, 5334]}
# 190278    {'line': '366-366', 'range': [12271, 12303]}
# 636113        {'line': '90-90', 'range': [4833, 4860]}
# 124885  {'line': '1089-1089', 'range': [44665, 44694]}
# 107566      {'line': '107-107', 'range': [5016, 5044]}
# 73425   {'line': '1658-1658', 'range': [73435, 73470]}
# 530600  {'line': '1695-1695', 'range': [75196, 75226]}
# 218002  {'line': '1036-1036', 'range': [44655, 44685]}
# 443725    {'line': '326-326', 'range': [15524, 15551]}
# 522487        {'line': '43-43', 'range': [1292, 1318]}
# 568672    {'line': '526-526', 'range': [20651, 20675]}
# 626145        {'line': '86-86', 'range': [5208, 5238]}
# 59647         {'line': '67-67', 'range': [4169, 4199]}
# 93370         {'line': '41-41', 'range': [1371, 1400]}
# 208815    {'line': '464-464', 'range': [15654, 15690]}
# 543143      {'line': '221-221', 'range': [6653, 6679]}
# 50868     {'line': '339-339', 'range': [15498, 15534]}
# 553389    {'line': '504-504', 'range': [20024, 20048]}
#
#         num_of_available_identifiers_to_choose_from  \
# 23718                                          1102
# 102132                                         1318
# 388527                                         1110
# 372610                                         1318
# 241712                                         1318
# 392550                                         1097
# 526949                                         1097
# 73572                                          1097
# 524839                                         1110
# 61565                                          1097
# 180692                                         1069
# 589370                                         1318
# 125670                                         1318
# 156384                                         1003
# 651555                                         1102
# 26520                                          1318
# 186630                                         1102
# 302787                                         1104
# 461033                                         1122
# 566746                                         1318
# 436076                                         1047
# 525762                                         1122
# 206818                                         1122
# 549008                                         1298
# 400251                                         1318
# 153687                                         1122
# 190278                                         1298
# 636113                                         1122
# 124885                                         1213
# 107566                                         1010
# 73425                                          1318
# 530600                                         1318
# 218002                                         1318
# 443725                                         1104
# 522487                                         1010
# 568672                                         1250
# 626145                                         1102
# 59647                                          1102
# 93370                                          1059
# 208815                                         1157
# 543143                                         1070
# 50868                                          1112
# 553389                                         1250
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 23718                                       1124  False           0.6664
# 102132                                      1116  False           0.6676
# 388527                                      1054  False           0.7144
# 372610                                      1116  False           0.7160
# 241712                                      1116  False           0.7160
# 392550                                      1053  False           0.7168
# 526949                                      1053  False           0.7184
# 73572                                       1053  False           0.7184
# 524839                                      1054  False           0.7212
# 61565                                       1053  False           0.7278
# 180692                                      1049  False           0.7284
# 589370                                      1116  False           0.7360
# 125670                                      1116  False           0.7362
# 156384                                      1002  False           0.7366
# 651555                                      1124  False           0.7420
# 26520                                       1116  False           0.7472
# 186630                                      1124  False           0.7524
# 302787                                      1028  False           0.7528
# 461033                                      1022  False           0.7546
# 566746                                      1116  False           0.7564
# 436076                                      1004  False           0.7572
# 525762                                      1022  False           0.7614
# 206818                                      1022  False           0.7614
# 549008                                      1137  False           0.7656
# 400251                                      1116  False           0.7662
# 153687                                      1022  False           0.7670
# 190278                                      1137  False           0.7680
# 636113                                      1022  False           0.7750
# 124885                                      1177  False           0.7814
# 107566                                      1068  False           0.7842
# 73425                                       1116  False           0.7902
# 530600                                      1116  False           0.7958
# 218002                                      1116  False           0.7958
# 443725                                      1028  False           0.8288
# 522487                                      1006  False           0.8296
# 568672                                      1127  False           0.8302
# 626145                                      1124  False           0.8456
# 59647                                       1124  False           0.8456
# 93370                                       1041  False           0.8478
# 208815                                      1039  False           0.8520
# 543143                                      1009  False           0.8652
# 50868                                       1019  False           0.8690
# 553389                                      1127  False           0.8820
#
#                                       seeding_pattern_url
# 23718   https://github.com/jquery/jquery/commit/0b36b2...
# 102132  https://github.com/jquery/jquery/commit/0b36b2...
# 388527  https://github.com/jquery/jquery/commit/0b36b2...
# 372610  https://github.com/jquery/jquery/commit/0b36b2...
# 241712  https://github.com/jquery/jquery/commit/0b36b2...
# 392550  https://github.com/jquery/jquery/commit/0b36b2...
# 526949  https://github.com/jquery/jquery/commit/0b36b2...
# 73572   https://github.com/jquery/jquery/commit/0b36b2...
# 524839  https://github.com/jquery/jquery/commit/0b36b2...
# 61565   https://github.com/jquery/jquery/commit/0b36b2...
# 180692  https://github.com/jquery/jquery/commit/0b36b2...
# 589370  https://github.com/jquery/jquery/commit/0b36b2...
# 125670  https://github.com/jquery/jquery/commit/0b36b2...
# 156384  https://github.com/jquery/jquery/commit/0b36b2...
# 651555  https://github.com/jquery/jquery/commit/0b36b2...
# 26520   https://github.com/jquery/jquery/commit/0b36b2...
# 186630  https://github.com/jquery/jquery/commit/0b36b2...
# 302787  https://github.com/jquery/jquery/commit/0b36b2...
# 461033  https://github.com/jquery/jquery/commit/0b36b2...
# 566746  https://github.com/jquery/jquery/commit/0b36b2...
# 436076  https://github.com/jquery/jquery/commit/0b36b2...
# 525762  https://github.com/jquery/jquery/commit/0b36b2...
# 206818  https://github.com/jquery/jquery/commit/0b36b2...
# 549008  https://github.com/jquery/jquery/commit/0b36b2...
# 400251  https://github.com/jquery/jquery/commit/0b36b2...
# 153687  https://github.com/jquery/jquery/commit/0b36b2...
# 190278  https://github.com/jquery/jquery/commit/0b36b2...
# 636113  https://github.com/jquery/jquery/commit/0b36b2...
# 124885  https://github.com/jquery/jquery/commit/0b36b2...
# 107566  https://github.com/jquery/jquery/commit/0b36b2...
# 73425   https://github.com/jquery/jquery/commit/0b36b2...
# 530600  https://github.com/jquery/jquery/commit/0b36b2...
# 218002  https://github.com/jquery/jquery/commit/0b36b2...
# 443725  https://github.com/jquery/jquery/commit/0b36b2...
# 522487  https://github.com/jquery/jquery/commit/0b36b2...
# 568672  https://github.com/jquery/jquery/commit/0b36b2...
# 626145  https://github.com/jquery/jquery/commit/0b36b2...
# 59647   https://github.com/jquery/jquery/commit/0b36b2...
# 93370   https://github.com/jquery/jquery/commit/0b36b2...
# 208815  https://github.com/jquery/jquery/commit/0b36b2...
# 543143  https://github.com/jquery/jquery/commit/0b36b2...
# 50868   https://github.com/jquery/jquery/commit/0b36b2...
# 553389  https://github.com/jquery/jquery/commit/0b36b2...

# %% [markdown]
# #### Change variable type

# %%
def get_type_of_value(val):
    nmbr = True
    if val == 'true' or val == 'false':
        return 'boolean'
    
    for c in val:
        if not c.isdigit():
            nmbr=False
    if nmbr:
        return 'number'
    return 'string'

selected_patterns = []
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    if ['Idf_1', '=', 'Lit_1']==pattern['fix'][0:3] and pattern['buggy'][0:3] == ['Idf_1', '=', 'Lit_2']:
            buggy_value = pattern['buggy_actual'][2]
            fix_value = pattern['fix_actual'][2]
            fx_type = get_type_of_value(fix_value)
            bg_type = get_type_of_value(buggy_value)
            if bg_type != fx_type:
                list_of_all_patterns_also_seded_by_mutandis.add(pattern['commit_hash'])
                selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 1
#               fix_actual        buggy_actual
# 0  [timerId, =, true, ;]  [timerId, =, 1, ;]

# %% [markdown]
# #### Matching seeded bug

# %%
p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[0,4]].sort_values(by='mean_similarity')
p
# Out:
#                                  file_name_where_intended  \
# 503082  benchmarks/data/thomaschampagne/StravaPlus/hoo...
# 602056  benchmarks/data/thomaschampagne/StravaPlus/hoo...
# 283385  benchmarks/data/creationix/js-git/net/transpor...
# 608986  benchmarks/data/yetone/collipa/collipa/static/...
# 514686  benchmarks/data/cdnjs/cdnjs/ajax/libs/moment.j...
# ...                                                   ...
# 638443  benchmarks/data/alduro/generator-flux-webapp/a...
# 202485  benchmarks/data/kyoung/trek/static/js/trek/mai...
# 382635             benchmarks/data/garyv/srcery/srcery.js
# 178165             benchmarks/data/garyv/srcery/srcery.js
# 188408             benchmarks/data/garyv/srcery/srcery.js
#
#            target_token_sequence-Correct    target_token_sequence-Buggy  \
# 503082                     [dp, =, 0, ;]                  [dp, =, 1, ;]
# 602056                     [dp, =, 0, ;]                  [dp, =, 1, ;]
# 283385               [verified, =, 2, ;]            [verified, =, 3, ;]
# 608986        [buttonImageURL, =, "", ;]      [buttonImageURL, =, 1, ;]
# 514686                  [input, =, 0, ;]               [input, =, 1, ;]
# ...                                  ...                            ...
# 638443             [started, =, true, ;]             [started, =, 1, ;]
# 202485  [displayCaptainsLog, =, true, ;]  [displayCaptainsLog, =, 1, ;]
# 382635             [queued, =, false, ;]              [queued, =, 1, ;]
# 178165              [queued, =, true, ;]              [queued, =, 1, ;]
# 188408              [queued, =, true, ;]              [queued, =, 1, ;]
#
#        token_sequence_abstraction-Correct token_sequence_abstraction-Buggy  \
# 503082               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 602056               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 283385               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 608986               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 514686               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# ...                                   ...                              ...
# 638443               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 202485               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 382635               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 178165               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
# 188408               [Idf_1, =, Lit_1, ;]             [Idf_1, =, Lit_2, ;]
#
#                                      target_line_range  \
# 503082        {'line': '37-37', 'range': [1272, 1279]}
# 602056        {'line': '41-41', 'range': [1372, 1379]}
# 283385        {'line': '45-45', 'range': [1926, 1939]}
# 608986    {'line': '421-421', 'range': [23066, 23086]}
# 514686  {'line': '1241-1241', 'range': [41775, 41785]}
# ...                                                ...
# 638443        {'line': '95-95', 'range': [3408, 3423]}
# 202485          {'line': '29-29', 'range': [824, 850]}
# 382635        {'line': '59-59', 'range': [2175, 2190]}
# 178165        {'line': '81-81', 'range': [2962, 2976]}
# 188408        {'line': '69-69', 'range': [2570, 2584]}
#
#         num_of_available_identifiers_to_choose_from  \
# 503082                                         1017
# 602056                                         1017
# 283385                                         1023
# 608986                                         1323
# 514686                                         1509
# ...                                             ...
# 638443                                         1050
# 202485                                         1016
# 382635                                         1031
# 178165                                         1031
# 188408                                         1031
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 503082                                      1020  False           0.3010
# 602056                                      1020  False           0.3010
# 283385                                      1020  False           0.3015
# 608986                                      1307  False           0.3050
# 514686                                      1262  False           0.3085
# ...                                          ...    ...              ...
# 638443                                      1064  False           0.7245
# 202485                                      1014  False           0.7330
# 382635                                      1012  False           0.7425
# 178165                                      1012  False           0.7785
# 188408                                      1012  False           0.7785
#
#                                       seeding_pattern_url
# 503082  https://github.com/jquery/jquery/commit/ab1504...
# 602056  https://github.com/jquery/jquery/commit/ab1504...
# 283385  https://github.com/jquery/jquery/commit/ab1504...
# 608986  https://github.com/jquery/jquery/commit/ab1504...
# 514686  https://github.com/jquery/jquery/commit/ab1504...
# ...                                                   ...
# 638443  https://github.com/jquery/jquery/commit/ab1504...
# 202485  https://github.com/jquery/jquery/commit/ab1504...
# 382635  https://github.com/jquery/jquery/commit/ab1504...
# 178165  https://github.com/jquery/jquery/commit/ab1504...
# 188408  https://github.com/jquery/jquery/commit/ab1504...
#
# [382 rows x 11 columns]

# %% [markdown]
# #### Swap Parameters
# **None Found**

# %%
selected_patterns = []
seen_url = set()
for _,r in patterns.iterrows():
    pattern = r.to_dict()
    if "(Idf_3,Idf_4)" in ''.join(pattern['fix']) and "(Idf_4,Idf_3)" in ''.join(pattern['buggy']):
        selected_patterns.append(pattern)
selected_patterns = pd.DataFrame(selected_patterns)
print(f'Number of selected patterns = {len(selected_patterns)}')
selected_patterns[['fix_actual','buggy_actual']]
# Out:
# Number of selected patterns = 10
#                                           fix_actual  \
# 0  [assert, ., strictEqual, (, completed, ,, expe...
# 1  [assert, ., strictEqual, (, chars_recved, ,, x...
# 2   [assert, ., strictEqual, (, cbcount, ,, N, ), ;]
# 3  [assert, ., strictEqual, (, returnedError, ,, ...
# 4  [assert, ., deepStrictEqual, (, actualChunks, ...
# 5  [assert, ., strictEqual, (, result, ,, expecte...
# 6  [assert, ., strictEqual, (, code, ,, expectCod...
# 7  [assert, ., strictEqual, (, result, ,, expecte...
# 8  [assert, ., strictEqual, (, err, ,, expected, ...
# 9  [assert, ., deepStrictEqual, (, rawHeaders, ,,...
#
#                                         buggy_actual
# 0  [assert, ., strictEqual, (, expected, ,, compl...
# 1  [assert, ., strictEqual, (, x, ,, chars_recved...
# 2   [assert, ., strictEqual, (, N, ,, cbcount, ), ;]
# 3  [assert, ., strictEqual, (, theError, ,, retur...
# 4  [assert, ., deepStrictEqual, (, expectChunks, ...
# 5  [assert, ., strictEqual, (, expected, ,, resul...
# 6  [assert, ., strictEqual, (, expectCode, ,, cod...
# 7  [assert, ., strictEqual, (, expected, ,, resul...
# 8  [assert, ., strictEqual, (, expected, ,, err, ...
# 9  [assert, ., deepStrictEqual, (, expected, ,, r...

# %% [markdown]
# #### Matching seeded bug

# %%
for i in range(len(selected_patterns)):
    p = seeded_bugs[seeded_bugs['seeding_pattern_url']==selected_patterns.iloc[i,4]].sort_values(by='mean_similarity')
    print(p)
# Out:
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []
# Empty DataFrame
# Columns: [file_name_where_intended, target_token_sequence-Correct, target_token_sequence-Buggy, token_sequence_abstraction-Correct, token_sequence_abstraction-Buggy, target_line_range, num_of_available_identifiers_to_choose_from, num_of_available_literals_to_choose_from, error, mean_similarity, seeding_pattern_url]
# Index: []

# %% [markdown]
# #### Remove Parameters

# %%
seeded_bugs[seeded_bugs['seeding_pattern_url']=='https://github.com/jquery/jquery/commit/ed1144816b07fbb2ea94217fd967626619344ad9'].sort_values(by='mean_similarity')
# Out:
#                                  file_name_where_intended  \
# 173030        benchmarks/data/kriszyp/xstyle/core/Rule.js
# 100776  benchmarks/data/SlexAxton/yepnope.js/src/yepno...
# 416465  benchmarks/data/buildfirst/buildfirst/appendix...
# 430644  benchmarks/data/buildfirst/buildfirst/appendix...
#
#                             target_token_sequence-Correct  \
# 173030  [value, =, generate, ., forSelector, (, value,...
# 100776  [url, =, yepnope, ., urlFormatter, (, url, ,, ...
# 416465  [result, =, _, ., difference, (, result, ,, ma...
# 430644  [result, =, _, ., union, (, result, ,, matches...
#
#                               target_token_sequence-Buggy  \
# 173030  [value, =, generate, ., forSelector, (, value,...
# 100776   [url, =, yepnope, ., urlFormatter, (, url, ), ;]
# 416465     [result, =, _, ., difference, (, result, ), ;]
# 430644          [result, =, _, ., union, (, result, ), ;]
#
#                        token_sequence_abstraction-Correct  \
# 173030  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ,, Idf_4...
# 100776  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ,, Idf_4...
# 416465  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ,, Idf_4...
# 430644  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ,, Idf_4...
#
#                    token_sequence_abstraction-Buggy  \
# 173030  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ), ;]
# 100776  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ), ;]
# 416465  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ), ;]
# 430644  [Idf_1, =, Idf_2, ., Idf_3, (, Idf_1, ), ;]
#
#                                  target_line_range  \
# 173030  {'line': '111-111', 'range': [4201, 4243]}
# 100776  {'line': '155-155', 'range': [4440, 4479]}
# 416465    {'line': '48-48', 'range': [1577, 1616]}
# 430644    {'line': '50-50', 'range': [1646, 1680]}
#
#         num_of_available_identifiers_to_choose_from  \
# 173030                                         1112
# 100776                                         1029
# 416465                                         1008
# 430644                                         1008
#
#         num_of_available_literals_to_choose_from  error  mean_similarity  \
# 173030                                      1019  False           0.3564
# 100776                                      1020  False           0.4146
# 416465                                      1021  False           0.4190
# 430644                                      1021  False           0.4344
#
#                                       seeding_pattern_url
# 173030  https://github.com/jquery/jquery/commit/ed1144...
# 100776  https://github.com/jquery/jquery/commit/ed1144...
# 416465  https://github.com/jquery/jquery/commit/ed1144...
# 430644  https://github.com/jquery/jquery/commit/ed1144...

# %%
print(f'Of {len(patterns)} patterns, {len(list_of_all_patterns_also_seded_by_mutandis)} could be seeded by mutandis')
# Out:
# Of 2880 patterns, 165 could be seeded by mutandis

# %%
seeded_bugs['commit_hash'] = seeded_bugs['seeding_pattern_url'].apply(lambda x: x.split('/')[-1])

# %%
possibly_seeded_by_mutandis = seeded_bugs.loc[seeded_bugs['commit_hash'].isin(list_of_all_patterns_also_seded_by_mutandis)]
print(f'Of all {len(seeded_bugs)} bugs, {len(possibly_seeded_by_mutandis)} could be possibly seeded by mutandis')
# Out:
# Of all 677217 bugs, 12787 could be possibly seeded by mutandis
